# %% [markdown]
# 산업통상자원부 공모전(빅데이터 분석 과제4): https://datacontest.kr/apply/applyAdd/3
# 기상청 종관기상관측(ASOS)자료: https://data.kma.go.kr/data/grnd/selectAsosRltmList.do?pgmNo=36
# 한국전력거래소_5분단위 전력수급현황: https://www.data.go.kr/data/15099819/fileData.do

# %% [markdown]
# # 기상정보를 활용한 실시간 전력수요 예측모델 개발

# %% [markdown]
# ##### ※ 본 프로젝트는 산업통상자원부에서 주최하는 2023년 제 11회 공공데이터 활용BI 공모전 빅데이터 분석 부문에 참여하면서 진행하였습니다.

# %% [markdown]
# - 프로젝트 주제: 기상정보를 활용한 실시간 전력수요 예측모델 개발
# - 분석 대상 기간: 23.3.13(월) ~ 23.3.19(일)(1주일)
# - 유의사항:
#   1. 향후 6시간까지의 5분 단위 예측 모델 제시
#   2. MAPE(Mean Absolute Percentage Error)로 제시

# %% [markdown]
# # EDA

# %% [markdown]
# ## 1. 전력데이터 EDA

# %% [markdown]
# ## 1) 전력데이터 불러오기 & 결합

# %% [markdown]
# * 전력수요량 추출을 위한 전력수급데이터와 기상변수량 추출을 위한 기상데이터 불러오기.
# * 먼저 데이터 제공기간이 더 짧은 전력데이터 탐색.
# * 일시 기준으로 전력수급데이터가 2012.06.01 ~ 2022.04.07과 2022.04.01 ~ 2023.04.30로 나눠져 있음.
# * 둘다 불러온다.

# %%
import pandas as pd 
df_ps = pd.read_csv("한국전력거래소_5분단위 전력수급현황(20120601~20220407).csv",encoding='cp949')
df_ps
# Out:
#                      기준일시  공급능력(MW)  현재수요(MW)  최대예측수요(MW)  공급예비력(MW)  \
# 0        2012-06-01 00:00   64355.0  51726.33       59400   12628.67
# 1        2012-06-01 00:05   64355.0  51342.53       60800   13012.47
# 2        2012-06-01 00:10   64355.0  51583.17       60800   12771.83
# 3        2012-06-01 00:15   64355.0  51631.69       60800   12723.31
# 4        2012-06-01 00:20   64355.0  51252.66       60800   13102.35
# ...                   ...       ...       ...         ...        ...
# 1035062  2022-04-07 23:35   82791.9  63877.30       69300   18914.70
# 1035063  2022-04-07 23:40   82768.1  63525.30       69300   19242.80
# 1035064  2022-04-07 23:45   82767.9  63506.20       69300   19261.70
# 1035065  2022-04-07 23:50   82762.4  62819.60       69300   19942.80
# 1035066  2022-04-07 23:55   82765.0  62445.80       69300   20319.10
#
#          공급예비율(퍼센트)  운영예비력(MW)  운영예비율(퍼센트)
# 0          24.41439   12628.67    24.41439
# 1          25.34442   13012.47    25.34442
# 2          24.75969   12771.83    24.75969
# 3          24.64245   12723.31    24.64245
# 4          25.56423   13102.35    25.56423
# ...             ...        ...         ...
# 1035062    29.61100   10803.00    16.91210
# 1035063    30.29160   10696.40    16.83800
# 1035064    30.33040   10501.30    16.53580
# 1035065    31.74610   10706.30    17.04290
# 1035066    32.53880   10835.90    17.35240
#
# [1035067 rows x 8 columns]

# %%
df_ps2 = pd.read_csv("한국전력거래소_5분단위 전력수급현황(20220401~20230430).csv",encoding='cp949')
df_ps2
# Out:
#                     기준일시  공급능력(MW)  현재수요(MW)  최대예측수요(MW)  공급예비력(MW)  \
# 0       2022-04-01 00:00  82494.25  62453.29       70100   20040.96
# 1       2022-04-01 00:05  83807.25  62329.25       70700   21477.99
# 2       2022-04-01 00:10  83799.12  61830.96       70700   21968.15
# 3       2022-04-01 00:15  83790.42  61648.72       70700   22141.69
# 4       2022-04-01 00:20  83770.82  61382.62       70700   22388.19
# ...                  ...       ...       ...         ...        ...
# 113638  2023-04-30 23:35  76101.03  53828.62       57300   22272.40
# 113639  2023-04-30 23:40  76084.24  53693.20       57300   22391.04
# 113640  2023-04-30 23:45  76083.32  52937.98       57300   23145.34
# 113641  2023-04-30 23:50  76077.47  52679.85       57300   23397.62
# 113642  2023-04-30 23:55  76072.29  52671.04       57300   23401.25
#
#         공급예비율(퍼센트)  운영예비력(MW)  운영예비율(퍼센트)
# 0         32.08951    9257.45    14.82300
# 1         34.45893   10889.28    17.47058
# 2         35.52937   10865.86    17.57350
# 3         35.91589   10864.26    17.62284
# 4         36.47318   10451.95    17.02754
# ...            ...        ...         ...
# 113638    41.37651    9389.09    17.44257
# 113639    41.70181    8897.85    16.57166
# 113640    43.72161    9257.95    17.48829
# 113641    44.41474    9303.84    17.66110
# 113642    44.42906    9508.00    18.05166
#
# [113643 rows x 8 columns]

# %% [markdown]
# * 기간이 겹치는 부분이 있음(2022-04-01 ~ 2022-04-07)
# * 해당범위 일시 데이터를 각각 불러와서 비교

# %%
# 첫번째 자료 2022-04-01 ~ 2022-04-07 데이터

# 기준일시를 날짜형식으로 변환
df_ps['기준일시'] = pd.to_datetime(df_ps['기준일시'])

# 2022-04-01부터 2022-04-07 23:55:00까지의 값을 찾기
start_date = pd.to_datetime('2022-04-01')
end_date = pd.to_datetime('2022-04-07 23:55:00')
df_ps_filtered = df_ps[(df_ps['기준일시'] >= start_date) & (df_ps['기준일시'] <= end_date)]
df_ps_filtered
# Out:
#                        기준일시  공급능력(MW)  현재수요(MW)  최대예측수요(MW)  공급예비력(MW)  \
# 1033176 2022-04-01 00:00:00   82494.3   62453.3       70100    20041.0
# 1033177 2022-04-01 00:05:00   83807.2   62329.3       70700    21478.0
# 1033178 2022-04-01 00:10:00   83799.1   61831.0       70700    21968.2
# 1033179 2022-04-01 00:15:00   83790.4   61648.7       70700    22141.7
# 1033180 2022-04-01 00:20:00   83770.8   61382.6       70700    22388.2
# ...                     ...       ...       ...         ...        ...
# 1035062 2022-04-07 23:35:00   82791.9   63877.3       69300    18914.7
# 1035063 2022-04-07 23:40:00   82768.1   63525.3       69300    19242.8
# 1035064 2022-04-07 23:45:00   82767.9   63506.2       69300    19261.7
# 1035065 2022-04-07 23:50:00   82762.4   62819.6       69300    19942.8
# 1035066 2022-04-07 23:55:00   82765.0   62445.8       69300    20319.1
#
#          공급예비율(퍼센트)  운영예비력(MW)  운영예비율(퍼센트)
# 1033176     32.0895    9257.46     14.8230
# 1033177     34.4589   10889.30     17.4706
# 1033178     35.5294   10865.90     17.5735
# 1033179     35.9159   10864.30     17.6228
# 1033180     36.4732   10452.00     17.0275
# ...             ...        ...         ...
# 1035062     29.6110   10803.00     16.9121
# 1035063     30.2916   10696.40     16.8380
# 1035064     30.3304   10501.30     16.5358
# 1035065     31.7461   10706.30     17.0429
# 1035066     32.5388   10835.90     17.3524
#
# [1891 rows x 8 columns]

# %%
# 두번째 자료 2022-04-01 ~ 2022-04-07 데이터

# 기준일시를 날짜형식으로 변환
df_ps2['기준일시'] = pd.to_datetime(df_ps2['기준일시'])

# 2022-04-01부터 2022-04-07 23:55:00까지의 값을 찾기
start_date = pd.to_datetime('2022-04-01')
end_date = pd.to_datetime('2022-04-07 23:55:00')
df_ps_filtered2 = df_ps2[(df_ps2['기준일시'] >= start_date) & (df_ps2['기준일시'] <= end_date)]
df_ps_filtered2
# Out:
#                     기준일시  공급능력(MW)  현재수요(MW)  최대예측수요(MW)  공급예비력(MW)  \
# 0    2022-04-01 00:00:00  82494.25  62453.29       70100   20040.96
# 1    2022-04-01 00:05:00  83807.25  62329.25       70700   21477.99
# 2    2022-04-01 00:10:00  83799.12  61830.96       70700   21968.15
# 3    2022-04-01 00:15:00  83790.42  61648.72       70700   22141.69
# 4    2022-04-01 00:20:00  83770.82  61382.62       70700   22388.19
# ...                  ...       ...       ...         ...        ...
# 2009 2022-04-07 23:35:00  82791.92  63877.26       69300   18914.66
# 2010 2022-04-07 23:40:00  82768.10  63525.30       69300   19242.80
# 2011 2022-04-07 23:45:00  82767.92  63506.23       69300   19261.68
# 2012 2022-04-07 23:50:00  82762.37  62819.60       69300   19942.77
# 2013 2022-04-07 23:55:00  82764.98  62445.84       69300   20319.13
#
#       공급예비율(퍼센트)  운영예비력(MW)  운영예비율(퍼센트)
# 0       32.08951    9257.45    14.82300
# 1       34.45893   10889.28    17.47058
# 2       35.52937   10865.86    17.57350
# 3       35.91589   10864.26    17.62284
# 4       36.47318   10451.95    17.02754
# ...          ...        ...         ...
# 2009    29.61095   10802.99    16.91210
# 2010    30.29156   10696.36    16.83795
# 2011    30.33039   10501.27    16.53581
# 2012    31.74610   10706.29    17.04291
# 2013    32.53881   10835.88    17.35244
#
# [2014 rows x 8 columns]

# %%
# 데이터 크기 비교 
print(df_ps_filtered.shape)
print(df_ps_filtered2.shape)
# Out:
# (1891, 8)
# (2014, 8)

# %% [markdown]
# * 데이터 크기가 다름.
# * 첫번째 자료에 결측값이 있어보임.
# * 필요한 자료가 현재수요 칼럼이므로 이 열을 기준으로 확인.

# %%
# 데이터프레임 병합
merged = pd.merge(df_ps_filtered, df_ps_filtered2, on='기준일시', how='outer')

# 기준일시가 있는 행과 없는 행 구분
missing_rows_df1 = merged[merged['현재수요(MW)_x'].notnull() & merged['현재수요(MW)_y'].isnull()]  # df_ps_filtered에만 있는 행
missing_rows_df2 = merged[merged['현재수요(MW)_x'].isnull() & merged['현재수요(MW)_y'].notnull()]  # df_ps_filtered2에만 있는 행

# 결과 출력
print("df_ps_filtered에만 있는 행:")
missing_rows_df1
print("df_ps_filtered2에만 있는 행:")
missing_rows_df2
# Out:
# df_ps_filtered에만 있는 행:
# df_ps_filtered2에만 있는 행:
#                     기준일시  공급능력(MW)_x  현재수요(MW)_x  최대예측수요(MW)_x  공급예비력(MW)_x  \
# 1891 2022-04-06 13:45:00         NaN         NaN           NaN          NaN
# 1892 2022-04-06 13:50:00         NaN         NaN           NaN          NaN
# 1893 2022-04-06 13:55:00         NaN         NaN           NaN          NaN
# 1894 2022-04-06 14:00:00         NaN         NaN           NaN          NaN
# 1895 2022-04-06 14:05:00         NaN         NaN           NaN          NaN
# ...                  ...         ...         ...           ...          ...
# 2009 2022-04-06 23:35:00         NaN         NaN           NaN          NaN
# 2010 2022-04-06 23:40:00         NaN         NaN           NaN          NaN
# 2011 2022-04-06 23:45:00         NaN         NaN           NaN          NaN
# 2012 2022-04-06 23:50:00         NaN         NaN           NaN          NaN
# 2013 2022-04-06 23:55:00         NaN         NaN           NaN          NaN
#
#       공급예비율(퍼센트)_x  운영예비력(MW)_x  운영예비율(퍼센트)_x  공급능력(MW)_y  현재수요(MW)_y  \
# 1891           NaN          NaN           NaN    84993.32    59939.30
# 1892           NaN          NaN           NaN    84990.17    60169.38
# 1893           NaN          NaN           NaN    84984.66    60086.69
# 1894           NaN          NaN           NaN    85038.34    60246.37
# 1895           NaN          NaN           NaN    84799.90    59972.00
# ...            ...          ...           ...         ...         ...
# 2009           NaN          NaN           NaN    83374.82    63386.87
# 2010           NaN          NaN           NaN    83378.75    63392.59
# 2011           NaN          NaN           NaN    83377.88    63102.06
# 2012           NaN          NaN           NaN    83372.41    62452.65
# 2013           NaN          NaN           NaN    83370.93    61857.57
#
#       최대예측수요(MW)_y  공급예비력(MW)_y  공급예비율(퍼센트)_y  운영예비력(MW)_y  운영예비율(퍼센트)_y
# 1891         70000     25054.01      41.79896     10001.39      16.68587
# 1892         70000     24820.79      41.25153      9743.93      16.19417
# 1893         70000     24897.97      41.43674      9835.63      16.36906
# 1894         70000     24791.96      41.15097      9797.07      16.26168
# 1895         70000     24827.90      41.39915      9956.65      16.60217
# ...            ...          ...           ...          ...           ...
# 2009         70000     19987.95      31.53327     11874.44      18.73329
# 2010         70000     19986.15      31.52758     11415.71      18.00796
# 2011         70000     20275.81      32.13178     11403.18      18.07101
# 2012         70000     20919.76      33.49699     11394.17      18.24449
# 2013         70000     21513.36      34.77887     11904.96      19.24576
#
# [123 rows x 15 columns]

# %% [markdown]
# * 확인결과 첫번째 자료에 결측값이 있고 두번째는 없었음.
# * 결측값은 두번째 자료로 대체
# * 나머지 겹치는 일시의 데이터들이 같은 값을 갖고 있는지 비교.

# %%
existing_rows = merged[merged['현재수요(MW)_x'].notnull() & merged['현재수요(MW)_y'].notnull()] 
print("기준일시가 있는 행:")
existing_rows
# Out:
# 기준일시가 있는 행:
#                     기준일시  공급능력(MW)_x  현재수요(MW)_x  최대예측수요(MW)_x  공급예비력(MW)_x  \
# 0    2022-04-01 00:00:00     82494.3     62453.3       70100.0      20041.0
# 1    2022-04-01 00:05:00     83807.2     62329.3       70700.0      21478.0
# 2    2022-04-01 00:10:00     83799.1     61831.0       70700.0      21968.2
# 3    2022-04-01 00:15:00     83790.4     61648.7       70700.0      22141.7
# 4    2022-04-01 00:20:00     83770.8     61382.6       70700.0      22388.2
# ...                  ...         ...         ...           ...          ...
# 1886 2022-04-07 23:35:00     82791.9     63877.3       69300.0      18914.7
# 1887 2022-04-07 23:40:00     82768.1     63525.3       69300.0      19242.8
# 1888 2022-04-07 23:45:00     82767.9     63506.2       69300.0      19261.7
# 1889 2022-04-07 23:50:00     82762.4     62819.6       69300.0      19942.8
# 1890 2022-04-07 23:55:00     82765.0     62445.8       69300.0      20319.1
#
#       공급예비율(퍼센트)_x  운영예비력(MW)_x  운영예비율(퍼센트)_x  공급능력(MW)_y  현재수요(MW)_y  \
# 0          32.0895      9257.46       14.8230    82494.25    62453.29
# 1          34.4589     10889.30       17.4706    83807.25    62329.25
# 2          35.5294     10865.90       17.5735    83799.12    61830.96
# 3          35.9159     10864.30       17.6228    83790.42    61648.72
# 4          36.4732     10452.00       17.0275    83770.82    61382.62
# ...            ...          ...           ...         ...         ...
# 1886       29.6110     10803.00       16.9121    82791.92    63877.26
# 1887       30.2916     10696.40       16.8380    82768.10    63525.30
# 1888       30.3304     10501.30       16.5358    82767.92    63506.23
# 1889       31.7461     10706.30       17.0429    82762.37    62819.60
# 1890       32.5388     10835.90       17.3524    82764.98    62445.84
#
#       최대예측수요(MW)_y  공급예비력(MW)_y  공급예비율(퍼센트)_y  운영예비력(MW)_y  운영예비율(퍼센트)_y
# 0            70100     20040.96      32.08951      9257.45      14.82300
# 1            70700     21477.99      34.45893     10889.28      17.47058
# 2            70700     21968.15      35.52937     10865.86      17.57350
# 3            70700     22141.69      35.91589     10864.26      17.62284
# 4            70700     22388.19      36.47318     10451.95      17.02754
# ...            ...          ...           ...          ...           ...
# 1886         69300     18914.66      29.61095     10802.99      16.91210
# 1887         69300     19242.80      30.29156     10696.36      16.83795
# 1888         69300     19261.68      30.33039     10501.27      16.53581
# 1889         69300     19942.77      31.74610     10706.29      17.04291
# 1890         69300     20319.13      32.53881     10835.88      17.35244
#
# [1891 rows x 15 columns]

# %% [markdown]
# * 소수점 단위로 차이가 있어 보임.
# * 첫번째 자료는 소수점 첫째자리까지 값이 있고 두번째 자료는 소수점 둘째자리까지 값이 있어서
#   첫째자리 기준으로 반올림하여 비교.
# * 필요한 자료는 현재수요 칼럼이므로 이 칼럼 끼리만 비교

# %%
# 두번째 자료 현재수요값 반올림

from decimal import Decimal, ROUND_HALF_UP

def round_current_demand(x):
    if isinstance(x, (int, float)):  # 숫자형인지 확인
        x = Decimal(str(x)).quantize(Decimal('0.0'), rounding=ROUND_HALF_UP)  # 숫자형으로 변환 후 반올림
    return x

existing_rows['현재수요(MW)_y'] = existing_rows['현재수요(MW)_y'].apply(round_current_demand)
pd.DataFrame(existing_rows['현재수요(MW)_y'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14804\2319256527.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   existing_rows['현재수요(MW)_y'] = existing_rows['현재수요(MW)_y'].apply(round_current_demand)
#      현재수요(MW)_y
# 0       62453.3
# 1       62329.3
# 2       61831.0
# 3       61648.7
# 4       61382.6
# ...         ...
# 1886    63877.3
# 1887    63525.3
# 1888    63506.2
# 1889    62819.6
# 1890    62445.8
#
# [1891 rows x 1 columns]

# %%
# 명시적인 숫자값 비교를 위해 문자형으로 변경
comp1 = existing_rows['현재수요(MW)_y'].astype(str)
comp2 = existing_rows['현재수요(MW)_x'].astype(str)

# 비교 
comparison = comp1 == comp2
value_counts = comparison.value_counts()
value_counts
# Out:
# True     1870
# False      21
# dtype: int64

# %% [markdown]
# * 21개 값이 다르다고 나왔다.
# * 값추출 후 비교

# %%
# 다른값 과 인덱스 찾기
false_indexes = comparison[comparison == False].index
false_values = comparison[comparison == False].values
extracted_rows = existing_rows.loc[false_indexes]
extracted_rows[['현재수요(MW)_x','현재수요(MW)_y']]
# Out:
#       현재수요(MW)_x 현재수요(MW)_y
# 202      66499.5    66499.6
# 266      66082.2    66082.3
# 690      48946.8    48946.7
# 741      44778.2    44778.3
# 874      55288.8    55288.7
# 934      57975.6    57975.5
# 1011     58633.1    58633.0
# 1064     65937.9    65937.8
# 1131     65520.9    65520.8
# 1161     59867.6    59867.5
# 1191     59307.1    59307.0
# 1195     59497.8    59497.7
# 1299     61192.9    61193.0
# 1316     62848.8    62848.7
# 1418     65698.6    65698.7
# 1565     63313.6    63313.5
# 1665     59513.4    59513.3
# 1783     60950.4    60950.5
# 1802     65291.6    65291.5
# 1844     68968.8    68968.7
# 1850     68254.2    68254.3

# %%
import numpy as np

# 연산을 위해 데이터타입 변환
extracted_rows['현재수요(MW)_x'] = extracted_rows['현재수요(MW)_x'].astype(float)
extracted_rows['현재수요(MW)_y'] = extracted_rows['현재수요(MW)_y'].astype(float)

# 두 칼럼 간 차이 계산
diff = np.abs(extracted_rows['현재수요(MW)_x'] - extracted_rows['현재수요(MW)_y'])

# 차이 값이 1 이하인 경우 True, 1을 초과하는 경우 False로 설정
result = np.isclose(diff, 0.1, atol=1e-10)

# 결과 출력
false_count = len(result) - result.sum()
print(false_count)
# Out:
# 0

# %% [markdown]
# * 다른 값은 전부 차이가 0.1 이하다.
# * 비슷하다고 판단하고 결측값이 없는 2번째 자료 기준으로 결합

# %%
# 기준일시, 현재수요 칼럼만 추출
df_cd = pd.DataFrame(df_ps[['기준일시','현재수요(MW)']])
df_cd2 = pd.DataFrame(df_ps2[['기준일시','현재수요(MW)']])

# 첫번째 데이터프레임을 기준으로 두 데이터프레임 합치기
merged = pd.merge(df_cd, df_cd2, on='기준일시', how='outer', suffixes=('_df1', '_df2'))

# 같은 값이 있는 경우 첫번째 데이터프레임의 값으로 채우기
merged['현재수요(MW)'] = merged['현재수요(MW)_df1'].combine_first(merged['현재수요(MW)_df2'])

# 기준일시 열과 불필요한 열 제거
merged.drop(['현재수요(MW)_df1', '현재수요(MW)_df2'], axis=1, inplace=True)

# 결과 출력
df_cd_merge = pd.DataFrame(merged)
df_cd_merge
# Out:
#                        기준일시  현재수요(MW)
# 0       2012-06-01 00:00:00  51726.33
# 1       2012-06-01 00:05:00  51342.53
# 2       2012-06-01 00:10:00  51583.17
# 3       2012-06-01 00:15:00  51631.69
# 4       2012-06-01 00:20:00  51252.66
# ...                     ...       ...
# 1146814 2023-04-30 23:35:00  53828.62
# 1146815 2023-04-30 23:40:00  53693.20
# 1146816 2023-04-30 23:45:00  52937.98
# 1146817 2023-04-30 23:50:00  52679.85
# 1146818 2023-04-30 23:55:00  52671.04
#
# [1146819 rows x 2 columns]

# %% [markdown]
# * 23.03.13 이전의 데이터를 뽑아야하기 때문에
#   필터링을 한다.

# %%
# '기준일시' 열을 datetime 형식으로 변환
df_cd_merge['기준일시'] = pd.to_datetime(df_cd_merge['기준일시'])

# 2023년 3월 12일 이전 데이터 추출
ED = df_cd_merge[df_cd_merge['기준일시'] <= '2023-03-12 23:55:00']

# 결과 출력
ED.reset_index(drop=True, inplace=True)
ED
# Out:
#                        기준일시  현재수요(MW)
# 0       2012-06-01 00:00:00  51726.33
# 1       2012-06-01 00:05:00  51342.53
# 2       2012-06-01 00:10:00  51583.17
# 3       2012-06-01 00:15:00  51631.69
# 4       2012-06-01 00:20:00  51252.66
# ...                     ...       ...
# 1132716 2023-03-12 23:35:00  60235.18
# 1132717 2023-03-12 23:40:00  60106.61
# 1132718 2023-03-12 23:45:00  59725.49
# 1132719 2023-03-12 23:50:00  59485.58
# 1132720 2023-03-12 23:55:00  58929.88
#
# [1132721 rows x 2 columns]

# %% [markdown]
# * 전력수요 데이터 추출 및 결합 끝.
# * 데이터 탐색 시작

# %% [markdown]
# ## 2) 전력수요 데이터 탐색

# %%
# 데이터 크기
ED.shape
# Out:
# (1132721, 2)

# %%
# 데이터 정보
ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545793 entries, 0 to 545792
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   기준일시      545793 non-null  datetime64[ns]
#  1   현재수요(MW)  545793 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 8.3 MB

# %%
# 결측값 확인
ED.isnull().sum()
# Out:
# 기준일시        0
# 현재수요(MW)    0
# dtype: int64

# %% [markdown]
# ## 3) 전력수요 데이터 시각화

# %%
import matplotlib.pyplot as plt

# 한글폰트설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 현재수요(MW) 칼럼의 이상치 탐색 함수
def detect_outliers(dataframe, column):
    Q1 = dataframe[column].quantile(0.25)
    Q3 = dataframe[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = dataframe[(dataframe[column] < lower_bound) | (dataframe[column] > upper_bound)]
    return outliers

# 현재수요(MW) 칼럼의 이상치 탐색
outliers = detect_outliers(ED, '현재수요(MW)')

# 이상치를 포함한 전체 데이터의 박스플롯 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(ED['현재수요(MW)'])
plt.xlabel('현재수요(MW)')
plt.ylabel('값')
plt.title('이상치 탐색 - 현재수요(MW)')
plt.show()

# 이상치를 포함한 데이터의 산점도 그리기

# 산점도 그리기
plt.figure(figsize=(12, 6))
plt.scatter(ED['기준일시'], ED['현재수요(MW)'], label='전체 데이터')
plt.scatter(outliers['기준일시'], outliers['현재수요(MW)'], color='red', label='이상치')
plt.xlabel('기준일시')
plt.ylabel('현재수요(MW)')
plt.title('이상치 탐색 - 현재수요(MW)')
plt.legend()
plt.show()

# %% [markdown]
# * 산점도를 보니 코로나가 있었던 2020년을 제외하면 2018년 이후로 전력수요량이 비슷한 경향을 보인다.
# * 2018년 이후로 이상치로 탐색된 지점은 그 이전 전력수요량 작았던 기간이 반영된 결과로 오히려 정상수치로 보임.
# * 히트맵으로도 알아보면

# %%
import seaborn as sns

# '기준일시' 열을 datetime 형식으로 변환
df_cd_merge['기준일시'] = pd.to_datetime(df_cd_merge['기준일시'])

# '년도', '월', '시간' 열 추가
df_cd_merge['년도'] = df_cd_merge['기준일시'].dt.year
df_cd_merge['월'] = df_cd_merge['기준일시'].dt.month
df_cd_merge['시간'] = df_cd_merge['기준일시'].dt.time

# 년도별로 데이터프레임 분할
df_yearly = df_cd_merge.groupby('년도')

# 히트맵 그리기
fig, axes = plt.subplots(len(df_yearly), figsize=(12, 4*len(df_yearly)), sharex=True, sharey=True)

vmin = 50000  # 범례의 최소값
vmax = 80000  # 범례의 최대값

for i, (year, group) in enumerate(df_yearly):
    # 월별 시간별 전력수요 피벗 테이블 생성
    pivot_table = group.pivot_table(index='시간', columns='월', values='현재수요(MW)')

    # 히트맵 그리기
    sns.heatmap(pivot_table, cmap='YlGnBu', ax=axes[i], vmin=vmin, vmax=vmax, cbar_kws={'fraction': 0.046})
    axes[i].set_title(f'{year} Yearly Hourly Demand Heatmap')
    axes[i].set_xlabel('Month')
    axes[i].set_ylabel('Time')
    axes[i].invert_yaxis()  # Y축 뒤집기

    # 시간 축 눈금 설정
    axes[i].set_xticks(range(0, 24, 6))

    # 월 축 눈금 설정
    axes[i].set_yticks(range(0, 24, 6))
    axes[i].set_yticklabels([''] * 4)  # 눈금 라벨 숨김

fig.subplots_adjust(hspace=0.3)  # 그래프의 상하 여백 조정
plt.show()

# %%
import seaborn as sns

# '기준일시' 열을 datetime 형식으로 변환
df_cd_merge['기준일시'] = pd.to_datetime(df_cd_merge['기준일시'])

# '년도', '월', '시간' 열 추가
df_cd_merge['년도'] = df_cd_merge['기준일시'].dt.year
df_cd_merge['월'] = df_cd_merge['기준일시'].dt.month
df_cd_merge['시간'] = df_cd_merge['기준일시'].dt.time

# 년도별로 데이터프레임 분할
df_yearly = df_cd_merge.groupby('년도')

# 히트맵 그리기
fig, axes = plt.subplots(len(df_yearly), figsize=(12, 4*len(df_yearly)), sharex=True, sharey=True)

vmin = 50000  # 범례의 최소값
vmax = 80000  # 범례의 최대값

for i, (year, group) in enumerate(df_yearly):
    # 월별 시간별 전력수요 피벗 테이블 생성
    pivot_table = group.pivot_table(index='시간', columns='월', values='현재수요(MW)')

    # 히트맵 그리기
    sns.heatmap(pivot_table, cmap='YlGnBu', ax=axes[i], vmin=vmin, vmax=vmax, cbar_kws={'fraction': 0.046})
    axes[i].set_title(f'{year} Yearly Hourly Demand Heatmap')
    axes[i].set_xlabel('Month')
    axes[i].set_ylabel('Time')
    axes[i].invert_yaxis()  # Y축 뒤집기

fig.subplots_adjust(hspace=0.3)  # 그래프의 상하 여백 조정
plt.show()

# %% [markdown]
# * 2018년부터 2023년 데이터와 유사해지기 시작.
# * 2022년이 가장 비슷하고 2020년이 코로나 탓에 다른 경향을 보임.
# * 2023년의 전력수요량을 예측하려면 2018년 자료부터 사용해야한다고 판단.

# %%
# 2018년부터 데이터 추출
ED = ED[ED['기준일시'] >= '2018-01-01 00:00:00']

# 결과 출력
ED.reset_index(drop=True, inplace=True)
ED
# Out:
#                       기준일시  현재수요(MW)
# 0      2018-01-01 00:00:00  60955.00
# 1      2018-01-01 00:05:00  60964.30
# 2      2018-01-01 00:10:00  60745.90
# 3      2018-01-01 00:15:00  60170.50
# 4      2018-01-01 00:20:00  60067.70
# ...                    ...       ...
# 545788 2023-03-12 23:35:00  60235.18
# 545789 2023-03-12 23:40:00  60106.61
# 545790 2023-03-12 23:45:00  59725.49
# 545791 2023-03-12 23:50:00  59485.58
# 545792 2023-03-12 23:55:00  58929.88
#
# [545793 rows x 2 columns]

# %% [markdown]
# * 2018년부터 2023년 3월 12일 까지 전력수요량 데이터를 모음.
# * 이 기간을 기준으로 변수데이터를 모을것.
# * 전력수요량 데이터 EDA 끝.
#
# * 잠시 예측해야할 2023-03-13~2023-03-13 전력수요량 데이터를 확인해보자.

# %%
# 필요한 기간의 데이터 추출
start_date = pd.to_datetime('2023-03-13')
end_date = pd.to_datetime('2023-03-19')
filtered_df = df_cd_merge[(df_cd_merge['기준일시'] >= start_date) & (df_cd_merge['기준일시'] <= end_date)]

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(filtered_df['기준일시'], filtered_df['현재수요(MW)'])
plt.xlabel('기준일시')
plt.ylabel('현재수요(MW)')
plt.title('2023년 3월 13일부터 3월 19일까지의 현재수요(MW)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 2. 기상데이터 EDA

# %% [markdown]
# ## 1) 기상데이터 불러오기 & 결합

# %% [markdown]
# * 기상정보데이터가 1년단위로 뽑힘.
#   2018년부터 2023년3월 12일까지 1년단위로 불러와 결합

# %%
weather_18 = pd.read_csv("2018기상정보.csv",encoding='cp949')
weather_18
# Out:
#          지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  \
# 0        90  속초  2018-01-01 00:00    -1.0       0.0      NaN        NaN
# 1        90  속초  2018-01-01 01:00    -2.1       0.0      NaN        NaN
# 2        90  속초  2018-01-01 02:00    -2.1       0.0      NaN        NaN
# 3        90  속초  2018-01-01 03:00    -2.2       0.0      NaN        NaN
# 4        90  속초  2018-01-01 04:00    -2.0       0.0      NaN        NaN
# ...     ...  ..               ...     ...       ...      ...        ...
# 831990  295  남해  2018-12-31 19:00     3.3       0.0      NaN        NaN
# 831991  295  남해  2018-12-31 20:00     3.2       0.0      NaN        NaN
# 831992  295  남해  2018-12-31 21:00     0.9       0.0      NaN        NaN
# 831993  295  남해  2018-12-31 22:00    -0.1       0.0      NaN        NaN
# 831994  295  남해  2018-12-31 23:00    -1.5       0.0      NaN        NaN
#
#         풍속(m/s)  풍속 QC플래그  풍향(16방위)  ...  현지기압(hPa)  현지기압 QC플래그  일조(hr)  \
# 0           1.1       NaN     250.0  ...     1019.4         0.0     NaN
# 1           1.7       0.0     230.0  ...     1019.7         0.0     NaN
# 2           1.4       0.0     160.0  ...     1020.1         0.0     NaN
# 3           0.9       0.0     230.0  ...     1020.4         0.0     NaN
# 4           1.2       0.0     250.0  ...     1020.4         0.0     NaN
# ...         ...       ...       ...  ...        ...         ...     ...
# 831990      1.2       0.0     270.0  ...     1027.6         0.0     NaN
# 831991      1.4       0.0     270.0  ...     1028.0         0.0     NaN
# 831992      0.6       0.0      50.0  ...     1028.1         0.0     NaN
# 831993      0.9       0.0     250.0  ...     1027.6         0.0     NaN
# 831994      0.6       0.0     250.0  ...     1027.5         0.0     NaN
#
#         일조 QC플래그  일사(MJ/m2)  일사 QC플래그  적설(cm)  전운량(10분위)  지면온도(°C)  지면온도 QC플래그
# 0            9.0        NaN       9.0     NaN        NaN      -2.3         0.0
# 1            9.0        NaN       9.0     NaN        NaN      -2.7         0.0
# 2            9.0        NaN       9.0     NaN        NaN      -3.0         0.0
# 3            9.0        NaN       9.0     NaN        NaN      -3.2         0.0
# 4            9.0        NaN       9.0     NaN        NaN      -3.3         0.0
# ...          ...        ...       ...     ...        ...       ...         ...
# 831990       9.0        NaN       9.0     NaN        4.0       0.8         0.0
# 831991       9.0        NaN       9.0     NaN        6.0       0.6         0.0
# 831992       9.0        NaN       9.0     NaN        0.0       0.1         0.0
# 831993       9.0        NaN       9.0     NaN        5.0      -0.3         0.0
# 831994       9.0        NaN       9.0     NaN        1.0      -0.9         0.0
#
# [831995 rows x 23 columns]

# %%
weather_19 = pd.read_csv("2019기상정보.csv",encoding='cp949')
weather_19
# Out:
#          지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  \
# 0        90  속초  2019-01-01 00:00    -2.5       0.0      NaN        NaN
# 1        90  속초  2019-01-01 01:00    -1.9       0.0      NaN        NaN
# 2        90  속초  2019-01-01 02:00    -2.2       0.0      NaN        NaN
# 3        90  속초  2019-01-01 03:00    -2.5       0.0      NaN        NaN
# 4        90  속초  2019-01-01 04:00    -3.9       0.0      NaN        NaN
# ...     ...  ..               ...     ...       ...      ...        ...
# 833788  295  남해  2019-12-31 19:00    -0.6       NaN      NaN        NaN
# 833789  295  남해  2019-12-31 20:00    -1.9       NaN      NaN        NaN
# 833790  295  남해  2019-12-31 21:00    -2.8       NaN      NaN        NaN
# 833791  295  남해  2019-12-31 22:00    -3.2       NaN      NaN        NaN
# 833792  295  남해  2019-12-31 23:00    -4.4       NaN      NaN        NaN
#
#         풍속(m/s)  풍속 QC플래그  풍향(16방위)  ...  현지기압(hPa)  현지기압 QC플래그  일조(hr)  \
# 0           0.8       0.0     320.0  ...     1028.9         0.0     NaN
# 1           0.6       NaN     360.0  ...     1028.8         0.0     NaN
# 2           1.4       NaN     340.0  ...     1028.6         0.0     NaN
# 3           1.4       NaN     340.0  ...     1028.7         0.0     NaN
# 4           0.5       NaN     290.0  ...     1027.9         0.0     NaN
# ...         ...       ...       ...  ...        ...         ...     ...
# 833788      1.2       NaN     270.0  ...     1026.3         NaN     NaN
# 833789      1.0       NaN     270.0  ...     1026.0         NaN     NaN
# 833790      0.7       NaN     250.0  ...     1026.2         NaN     NaN
# 833791      0.6       NaN     270.0  ...     1026.2         NaN     NaN
# 833792      0.4       NaN       0.0  ...     1026.2         NaN     NaN
#
#         일조 QC플래그  일사(MJ/m2)  일사 QC플래그  적설(cm)  전운량(10분위)  지면온도(°C)  지면온도 QC플래그
# 0            9.0        NaN       9.0     NaN        2.0      -4.9         0.0
# 1            9.0        NaN       9.0     NaN        0.0      -5.6         0.0
# 2            9.0        NaN       9.0     NaN        0.0      -5.3         0.0
# 3            9.0        NaN       9.0     NaN        2.0      -6.0         0.0
# 4            9.0        NaN       9.0     NaN        0.0      -6.6         0.0
# ...          ...        ...       ...     ...        ...       ...         ...
# 833788       9.0        NaN       9.0     NaN        0.0       0.1         NaN
# 833789       9.0        NaN       9.0     NaN        0.0      -0.6         NaN
# 833790       9.0        NaN       9.0     NaN        NaN      -1.2         NaN
# 833791       9.0        NaN       9.0     NaN        0.0      -1.8         NaN
# 833792       9.0        NaN       9.0     NaN        0.0      -2.2         NaN
#
# [833793 rows x 23 columns]

# %%
weather_20 = pd.read_csv("2020기상정보.csv",encoding='cp949')
weather_20
# Out:
#          지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  \
# 0        90  속초  2020-01-01 00:00    -2.6       NaN      NaN        NaN
# 1        90  속초  2020-01-01 01:00    -2.5       NaN      NaN        NaN
# 2        90  속초  2020-01-01 02:00    -2.5       NaN      NaN        NaN
# 3        90  속초  2020-01-01 03:00    -2.0       NaN      NaN        NaN
# 4        90  속초  2020-01-01 04:00    -1.7       NaN      NaN        NaN
# ...     ...  ..               ...     ...       ...      ...        ...
# 834473  295  남해  2020-12-31 19:00     1.0       NaN      NaN        NaN
# 834474  295  남해  2020-12-31 20:00     0.7       NaN      NaN        NaN
# 834475  295  남해  2020-12-31 21:00     0.3       NaN      NaN        NaN
# 834476  295  남해  2020-12-31 22:00     0.6       NaN      NaN        NaN
# 834477  295  남해  2020-12-31 23:00     0.4       NaN      NaN        NaN
#
#         풍속(m/s)  풍속 QC플래그  풍향(16방위)  ...  현지기압(hPa)  현지기압 QC플래그  일조(hr)  \
# 0           3.1       NaN     180.0  ...     1025.2         NaN     NaN
# 1           2.1       NaN     230.0  ...     1024.9         NaN     NaN
# 2           1.0       NaN     230.0  ...     1024.3         NaN     NaN
# 3           2.0       NaN     180.0  ...     1024.1         NaN     NaN
# 4           2.6       NaN     250.0  ...     1023.8         NaN     NaN
# ...         ...       ...       ...  ...        ...         ...     ...
# 834473      3.2       NaN     320.0  ...     1019.2         NaN     NaN
# 834474      3.2       NaN     320.0  ...     1019.3         NaN     NaN
# 834475      0.8       NaN     250.0  ...     1019.6         NaN     NaN
# 834476      1.9       NaN     270.0  ...     1019.5         NaN     NaN
# 834477      2.3       NaN     250.0  ...     1019.8         NaN     NaN
#
#         일조 QC플래그  일사(MJ/m2)  일사 QC플래그  적설(cm)  전운량(10분위)  지면온도(°C)  지면온도 QC플래그
# 0            9.0        NaN       9.0     NaN        1.0      -2.6         NaN
# 1            9.0        NaN       9.0     NaN        0.0      -2.6         NaN
# 2            9.0        NaN       9.0     NaN        1.0      -2.7         NaN
# 3            9.0        NaN       9.0     NaN        1.0      -2.6         NaN
# 4            9.0        NaN       9.0     NaN        0.0      -2.5         NaN
# ...          ...        ...       ...     ...        ...       ...         ...
# 834473       9.0        NaN       9.0     NaN        6.0       0.8         NaN
# 834474       9.0        NaN       9.0     NaN        1.0       0.8         NaN
# 834475       9.0        NaN       9.0     NaN        3.0       0.6         NaN
# 834476       9.0        NaN       9.0     NaN        7.0       0.6         NaN
# 834477       9.0        NaN       9.0     NaN        3.0       0.5         NaN
#
# [834478 rows x 23 columns]

# %%
weather_21 = pd.read_csv("2021기상정보.csv",encoding='cp949')
weather_21
# Out:
#          지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  \
# 0        90  속초  2021-01-01 00:00    -6.3       NaN      NaN        NaN
# 1        90  속초  2021-01-01 01:00    -6.7       NaN      NaN        NaN
# 2        90  속초  2021-01-01 02:00    -6.7       NaN      NaN        NaN
# 3        90  속초  2021-01-01 03:00    -7.2       NaN      NaN        NaN
# 4        90  속초  2021-01-01 04:00    -7.6       NaN      NaN        NaN
# ...     ...  ..               ...     ...       ...      ...        ...
# 832195  295  남해  2021-12-31 19:00    -0.5       NaN      NaN        NaN
# 832196  295  남해  2021-12-31 20:00    -1.3       NaN      NaN        NaN
# 832197  295  남해  2021-12-31 21:00    -1.7       NaN      NaN        NaN
# 832198  295  남해  2021-12-31 22:00    -3.2       NaN      NaN        NaN
# 832199  295  남해  2021-12-31 23:00    -2.8       NaN      NaN        NaN
#
#         풍속(m/s)  풍속 QC플래그  풍향(16방위)  ...  현지기압(hPa)  현지기압 QC플래그  일조(hr)  \
# 0           2.6       NaN     290.0  ...     1020.3         NaN     NaN
# 1           4.3       NaN     320.0  ...     1020.4         NaN     NaN
# 2           2.0       NaN     340.0  ...     1021.2         NaN     NaN
# 3           1.3       NaN     320.0  ...     1022.0         NaN     NaN
# 4           0.8       NaN     180.0  ...     1021.7         NaN     NaN
# ...         ...       ...       ...  ...        ...         ...     ...
# 832195      1.1       NaN     270.0  ...     1023.3         NaN     NaN
# 832196      1.0       NaN     270.0  ...     1023.7         NaN     NaN
# 832197      1.0       NaN     250.0  ...     1024.0         NaN     NaN
# 832198      0.6       NaN     250.0  ...     1024.4         NaN     NaN
# 832199      0.9       NaN     230.0  ...     1024.6         NaN     NaN
#
#         일조 QC플래그  일사(MJ/m2)  일사 QC플래그  적설(cm)  전운량(10분위)  지면온도(°C)  지면온도 QC플래그
# 0            9.0        NaN       9.0     NaN        0.0      -7.0         NaN
# 1            9.0        NaN       9.0     NaN        0.0      -6.9         NaN
# 2            9.0        NaN       9.0     NaN        0.0      -7.8         NaN
# 3            9.0        NaN       9.0     NaN        0.0      -8.7         NaN
# 4            9.0        NaN       9.0     NaN        2.0      -9.6         NaN
# ...          ...        ...       ...     ...        ...       ...         ...
# 832195       9.0        NaN       9.0     NaN        0.0      -0.5         NaN
# 832196       9.0        NaN       9.0     NaN        3.0      -0.8         NaN
# 832197       9.0        NaN       9.0     NaN        2.0      -1.2         NaN
# 832198       9.0        NaN       9.0     NaN        8.0      -1.4         NaN
# 832199       9.0        NaN       9.0     NaN        6.0      -1.6         NaN
#
# [832200 rows x 23 columns]

# %%
weather_22 = pd.read_csv("2022기상정보.csv",encoding='cp949')
weather_22
# Out:
#          지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  \
# 0        90  속초  2022-01-01 00:00    -5.8       NaN      NaN        NaN
# 1        90  속초  2022-01-01 01:00    -7.7       NaN      NaN        NaN
# 2        90  속초  2022-01-01 02:00    -8.0       NaN      NaN        NaN
# 3        90  속초  2022-01-01 03:00    -8.3       NaN      NaN        NaN
# 4        90  속초  2022-01-01 04:00    -8.2       NaN      NaN        NaN
# ...     ...  ..               ...     ...       ...      ...        ...
# 832195  295  남해  2022-12-31 19:00     3.5       NaN      NaN        NaN
# 832196  295  남해  2022-12-31 20:00     2.8       NaN      NaN        NaN
# 832197  295  남해  2022-12-31 21:00     2.4       NaN      NaN        NaN
# 832198  295  남해  2022-12-31 22:00    -0.5       NaN      NaN        NaN
# 832199  295  남해  2022-12-31 23:00    -0.8       NaN      NaN        NaN
#
#         풍속(m/s)  풍속 QC플래그  풍향(16방위)  ...  현지기압(hPa)  현지기압 QC플래그  일조(hr)  \
# 0           1.1       NaN     320.0  ...     1026.1         NaN     NaN
# 1           1.5       NaN     270.0  ...     1026.6         NaN     NaN
# 2           1.9       NaN     270.0  ...     1027.2         NaN     NaN
# 3           1.3       NaN     270.0  ...     1027.8         NaN     NaN
# 4           1.5       NaN     270.0  ...     1027.4         NaN     NaN
# ...         ...       ...       ...  ...        ...         ...     ...
# 832195      2.4       NaN     270.0  ...     1023.9         NaN     NaN
# 832196      1.9       NaN     270.0  ...     1024.3         NaN     NaN
# 832197      1.7       NaN     270.0  ...     1024.0         NaN     NaN
# 832198      0.0       NaN       0.0  ...     1023.9         NaN     NaN
# 832199      0.0       NaN       0.0  ...     1024.5         NaN     NaN
#
#         일조 QC플래그  일사(MJ/m2)  일사 QC플래그  적설(cm)  전운량(10분위)  지면온도(°C)  지면온도 QC플래그
# 0            9.0        NaN       9.0    22.1        0.0       0.6         NaN
# 1            9.0        NaN       9.0    22.1        1.0       0.6         NaN
# 2            9.0        NaN       9.0    22.1        1.0       0.6         NaN
# 3            9.0        NaN       9.0    22.1        1.0       0.6         NaN
# 4            9.0        NaN       9.0    22.1        2.0       0.6         NaN
# ...          ...        ...       ...     ...        ...       ...         ...
# 832195       9.0        NaN       9.0     NaN        0.0       0.9         NaN
# 832196       9.0        NaN       9.0     NaN        0.0       0.3         NaN
# 832197       9.0        NaN       9.0     NaN        0.0       0.0         NaN
# 832198       9.0        NaN       9.0     NaN        3.0      -0.5         NaN
# 832199       9.0        NaN       9.0     NaN        0.0      -0.9         NaN
#
# [832200 rows x 23 columns]

# %%
weather_23 = pd.read_csv("2023기상정보.csv",encoding='cp949')
weather_23
# Out:
#          지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  \
# 0        90  속초  2023-01-01 00:00     3.4       NaN      NaN        NaN
# 1        90  속초  2023-01-01 01:00     3.0       NaN      NaN        NaN
# 2        90  속초  2023-01-01 02:00     2.7       NaN      NaN        NaN
# 3        90  속초  2023-01-01 03:00     2.7       NaN      NaN        NaN
# 4        90  속초  2023-01-01 04:00     2.7       NaN      NaN        NaN
# ...     ...  ..               ...     ...       ...      ...        ...
# 161875  295  남해  2023-03-12 19:00     7.6       NaN      NaN        9.0
# 161876  295  남해  2023-03-12 20:00     6.1       NaN      NaN        9.0
# 161877  295  남해  2023-03-12 21:00     4.9       NaN      NaN        9.0
# 161878  295  남해  2023-03-12 22:00     3.8       NaN      NaN        9.0
# 161879  295  남해  2023-03-12 23:00     3.4       NaN      NaN        9.0
#
#         풍속(m/s)  풍속 QC플래그  풍향(16방위)  ...  현지기압(hPa)  현지기압 QC플래그  일조(hr)  \
# 0           8.8       NaN     290.0  ...     1022.5         NaN     NaN
# 1           2.9       NaN     290.0  ...     1023.7         NaN     NaN
# 2           3.7       NaN     270.0  ...     1023.1         NaN     NaN
# 3           3.3       NaN     270.0  ...     1022.6         NaN     NaN
# 4           2.2       NaN     320.0  ...     1022.8         NaN     NaN
# ...         ...       ...       ...  ...        ...         ...     ...
# 161875      4.5       NaN     320.0  ...     1014.0         NaN     0.0
# 161876      3.8       NaN     290.0  ...     1014.9         NaN     NaN
# 161877      4.4       NaN     290.0  ...     1015.9         NaN     NaN
# 161878      6.4       NaN     290.0  ...     1016.8         NaN     NaN
# 161879      5.4       NaN     320.0  ...     1017.4         NaN     NaN
#
#         일조 QC플래그  일사(MJ/m2)  일사 QC플래그  적설(cm)  전운량(10분위)  지면온도(°C)  지면온도 QC플래그
# 0            9.0        NaN       9.0     NaN        0.0      -0.1         NaN
# 1            9.0        NaN       9.0     NaN        0.0      -0.3         NaN
# 2            9.0        NaN       9.0     NaN        2.0      -0.6         NaN
# 3            9.0        NaN       9.0     NaN        0.0      -0.7         NaN
# 4            9.0        NaN       9.0     NaN        1.0      -1.3         NaN
# ...          ...        ...       ...     ...        ...       ...         ...
# 161875       NaN        NaN       9.0     NaN       10.0       7.1         NaN
# 161876       9.0        NaN       9.0     NaN       10.0       5.5         NaN
# 161877       9.0        NaN       9.0     NaN        9.0       3.9         NaN
# 161878       9.0        NaN       9.0     NaN        1.0       2.0         NaN
# 161879       9.0        NaN       9.0     NaN        4.0       1.2         NaN
#
# [161880 rows x 23 columns]

# %% [markdown]
# ## 데이터 시각화

# %%
import seaborn as sns

# '기준일시' 열을 datetime 형식으로 변환
df_cd_merge['기준일시'] = pd.to_datetime(df_cd_merge['기준일시'])

# '년도', '월', '시간' 열 추가
df_cd_merge['년도'] = df_cd_merge['기준일시'].dt.year
df_cd_merge['월'] = df_cd_merge['기준일시'].dt.month
df_cd_merge['시간'] = df_cd_merge['기준일시'].dt.time

# 년도별로 데이터프레임 분할
df_yearly = df_cd_merge.groupby('년도')

# 히트맵 그리기
fig, axes = plt.subplots(len(df_yearly), figsize=(12, 6*len(df_yearly)), sharex=True, sharey=True)

for i, (year, group) in enumerate(df_yearly):
    # 월별 시간별 전력수요 피벗 테이블 생성
    pivot_table = group.pivot_table(index='시간', columns='월', values='현재수요(MW)')

    # 히트맵 그리기
    sns.heatmap(pivot_table, cmap='YlGnBu', ax=axes[i])
    axes[i].set_title(f'{year} Yearly Hourly Demand Heatmap')
    axes[i].set_xlabel('Time')
    axes[i].set_ylabel('Month')

plt.tight_layout()
plt.show()

# %%
pd.DataFrame(filtered_df[in_df1])
# Out:
#                        기준일시  공급능력(MW)  현재수요(MW)  최대예측수요(MW)  공급예비력(MW)  \
# 1033176 2022-04-01 00:00:00   82494.3   62453.3       70100    20041.0
# 1033177 2022-04-01 00:05:00   83807.2   62329.3       70700    21478.0
# 1033178 2022-04-01 00:10:00   83799.1   61831.0       70700    21968.2
# 1033179 2022-04-01 00:15:00   83790.4   61648.7       70700    22141.7
# 1033180 2022-04-01 00:20:00   83770.8   61382.6       70700    22388.2
# ...                     ...       ...       ...         ...        ...
# 1035062 2022-04-07 23:35:00   82791.9   63877.3       69300    18914.7
# 1035063 2022-04-07 23:40:00   82768.1   63525.3       69300    19242.8
# 1035064 2022-04-07 23:45:00   82767.9   63506.2       69300    19261.7
# 1035065 2022-04-07 23:50:00   82762.4   62819.6       69300    19942.8
# 1035066 2022-04-07 23:55:00   82765.0   62445.8       69300    20319.1
#
#          공급예비율(퍼센트)  운영예비력(MW)  운영예비율(퍼센트)
# 1033176     32.0895    9257.46     14.8230
# 1033177     34.4589   10889.30     17.4706
# 1033178     35.5294   10865.90     17.5735
# 1033179     35.9159   10864.30     17.6228
# 1033180     36.4732   10452.00     17.0275
# ...             ...        ...         ...
# 1035062     29.6110   10803.00     16.9121
# 1035063     30.2916   10696.40     16.8380
# 1035064     30.3304   10501.30     16.5358
# 1035065     31.7461   10706.30     17.0429
# 1035066     32.5388   10835.90     17.3524
#
# [1891 rows x 8 columns]

# %%
df_ps_merged = pd.merge(df_ps, df_ps2, on='기준일시')
df_ps_merged
# Out:
#                   기준일시  공급능력(MW)_x  현재수요(MW)_x  최대예측수요(MW)_x  공급예비력(MW)_x  \
# 0     2022-04-01 00:00     82494.3     62453.3         70100      20041.0
# 1     2022-04-01 00:05     83807.2     62329.3         70700      21478.0
# 2     2022-04-01 00:10     83799.1     61831.0         70700      21968.2
# 3     2022-04-01 00:15     83790.4     61648.7         70700      22141.7
# 4     2022-04-01 00:20     83770.8     61382.6         70700      22388.2
# ...                ...         ...         ...           ...          ...
# 1886  2022-04-07 23:35     82791.9     63877.3         69300      18914.7
# 1887  2022-04-07 23:40     82768.1     63525.3         69300      19242.8
# 1888  2022-04-07 23:45     82767.9     63506.2         69300      19261.7
# 1889  2022-04-07 23:50     82762.4     62819.6         69300      19942.8
# 1890  2022-04-07 23:55     82765.0     62445.8         69300      20319.1
#
#       공급예비율(퍼센트)_x  운영예비력(MW)_x  운영예비율(퍼센트)_x  공급능력(MW)_y  현재수요(MW)_y  \
# 0          32.0895      9257.46       14.8230    82494.25    62453.29
# 1          34.4589     10889.30       17.4706    83807.25    62329.25
# 2          35.5294     10865.90       17.5735    83799.12    61830.96
# 3          35.9159     10864.30       17.6228    83790.42    61648.72
# 4          36.4732     10452.00       17.0275    83770.82    61382.62
# ...            ...          ...           ...         ...         ...
# 1886       29.6110     10803.00       16.9121    82791.92    63877.26
# 1887       30.2916     10696.40       16.8380    82768.10    63525.30
# 1888       30.3304     10501.30       16.5358    82767.92    63506.23
# 1889       31.7461     10706.30       17.0429    82762.37    62819.60
# 1890       32.5388     10835.90       17.3524    82764.98    62445.84
#
#       최대예측수요(MW)_y  공급예비력(MW)_y  공급예비율(퍼센트)_y  운영예비력(MW)_y  운영예비율(퍼센트)_y
# 0            70100     20040.96      32.08951      9257.45      14.82300
# 1            70700     21477.99      34.45893     10889.28      17.47058
# 2            70700     21968.15      35.52937     10865.86      17.57350
# 3            70700     22141.69      35.91589     10864.26      17.62284
# 4            70700     22388.19      36.47318     10451.95      17.02754
# ...            ...          ...           ...          ...           ...
# 1886         69300     18914.66      29.61095     10802.99      16.91210
# 1887         69300     19242.80      30.29156     10696.36      16.83795
# 1888         69300     19261.68      30.33039     10501.27      16.53581
# 1889         69300     19942.77      31.74610     10706.29      17.04291
# 1890         69300     20319.13      32.53881     10835.88      17.35244
#
# [1891 rows x 15 columns]

# %%
기준일시가 겹치는 부분이 있음.결합.

# %%
import pandas as pd

# 기상정보
df_weather = pd.read_csv("기상정보.csv")
df_weather = df_weather.drop('Unnamed: 0',axis=1)
df_weather
# Out:
#          지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  \
# 0        90  속초  2022-04-01 00:00     3.8       NaN      NaN        9.0
# 1        90  속초  2022-04-01 01:00     3.4       NaN      NaN        NaN
# 2        90  속초  2022-04-01 02:00     2.8       NaN      NaN        NaN
# 3        90  속초  2022-04-01 03:00     2.4       NaN      NaN        NaN
# 4        90  속초  2022-04-01 04:00     2.9       NaN      NaN        NaN
# ...     ...  ..               ...     ...       ...      ...        ...
# 830010  295  남해  2023-03-30 20:00    14.2       NaN      NaN        NaN
# 830011  295  남해  2023-03-30 21:00    13.9       NaN      NaN        NaN
# 830012  295  남해  2023-03-30 22:00    13.3       NaN      NaN        NaN
# 830013  295  남해  2023-03-30 23:00    13.0       NaN      NaN        NaN
# 830014  295  남해  2023-03-31 00:00    12.9       NaN      NaN        NaN
#
#         풍속(m/s)  풍속 QC플래그  풍향(16방위)  ...  현지기압 QC플래그  해면기압(hPa)  해면기압 QC플래그  \
# 0           1.3       NaN     270.0  ...         NaN     1029.5         NaN
# 1           1.4       NaN     290.0  ...         NaN     1029.9         NaN
# 2           1.7       NaN     290.0  ...         NaN     1029.9         NaN
# 3           1.9       NaN     290.0  ...         NaN     1029.9         NaN
# 4           1.1       NaN     320.0  ...         NaN     1030.3         NaN
# ...         ...       ...       ...  ...         ...        ...         ...
# 830010      0.3       NaN       0.0  ...         NaN     1018.0         NaN
# 830011      0.3       NaN       0.0  ...         NaN     1018.4         NaN
# 830012      0.4       NaN       0.0  ...         NaN     1018.4         NaN
# 830013      0.7       NaN     250.0  ...         NaN     1018.6         NaN
# 830014      0.7       NaN     250.0  ...         NaN     1018.7         NaN
#
#         일조(hr)  일조 QC플래그  일사(MJ/m2)  일사 QC플래그  적설(cm)  지면온도(°C)  지면온도 QC플래그
# 0          NaN       9.0        NaN       9.0     NaN       3.9         NaN
# 1          NaN       9.0        NaN       9.0     NaN       3.1         NaN
# 2          NaN       9.0        NaN       9.0     NaN       2.6         NaN
# 3          NaN       9.0        NaN       9.0     NaN       2.3         NaN
# 4          NaN       9.0        NaN       9.0     NaN       2.3         NaN
# ...        ...       ...        ...       ...     ...       ...         ...
# 830010     NaN       9.0        NaN       9.0     NaN      12.6         NaN
# 830011     NaN       9.0        NaN       9.0     NaN      11.8         NaN
# 830012     NaN       9.0        NaN       9.0     NaN      10.8         NaN
# 830013     NaN       9.0        NaN       9.0     NaN      10.8         NaN
# 830014     NaN       9.0        NaN       9.0     NaN      10.5         NaN
#
# [830015 rows x 24 columns]

# %%
df_weather2 = pd.read_csv("기상정보2.csv",encoding ='cp949')
df_weather2
# Out:
#         지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  \
# 0       90  속초  2023-03-31 01:00    16.9       NaN      NaN        NaN
# 1       90  속초  2023-03-31 02:00    16.9       NaN      NaN        NaN
# 2       90  속초  2023-03-31 03:00    17.1       NaN      NaN        NaN
# 3       90  속초  2023-03-31 04:00    16.2       NaN      NaN        NaN
# 4       90  속초  2023-03-31 05:00    14.9       NaN      NaN        NaN
# ...    ...  ..               ...     ...       ...      ...        ...
# 70676  295  남해  2023-04-30 20:00    16.0       NaN      NaN        NaN
# 70677  295  남해  2023-04-30 21:00    15.4       NaN      NaN        NaN
# 70678  295  남해  2023-04-30 22:00    12.8       NaN      NaN        NaN
# 70679  295  남해  2023-04-30 23:00    14.3       NaN      NaN        NaN
# 70680  295  남해  2023-05-01 00:00    15.5       NaN      NaN        NaN
#
#        풍속(m/s)  풍속 QC플래그  풍향(16방위)  ...  현지기압 QC플래그  해면기압(hPa)  해면기압 QC플래그  \
# 0          0.6       NaN     200.0  ...         NaN     1016.5         NaN
# 1          1.3       NaN     360.0  ...         NaN     1016.5         NaN
# 2          1.8       NaN     290.0  ...         NaN     1016.2         NaN
# 3          1.7       NaN     270.0  ...         NaN     1016.3         NaN
# 4          0.9       NaN     200.0  ...         NaN     1016.6         NaN
# ...        ...       ...       ...  ...         ...        ...         ...
# 70676      0.5       NaN     290.0  ...         NaN     1011.8         NaN
# 70677      0.6       NaN     250.0  ...         NaN     1012.8         NaN
# 70678      0.5       NaN     290.0  ...         NaN     1013.2         NaN
# 70679      0.3       NaN       0.0  ...         NaN     1013.1         NaN
# 70680      1.8       NaN     290.0  ...         NaN     1013.2         NaN
#
#        일조(hr)  일조 QC플래그  일사(MJ/m2)  일사 QC플래그  적설(cm)  지면온도(°C)  지면온도 QC플래그
# 0         NaN       9.0        NaN       9.0     NaN       8.9         NaN
# 1         NaN       9.0        NaN       9.0     NaN       8.9         NaN
# 2         NaN       9.0        NaN       9.0     NaN       8.5         NaN
# 3         NaN       9.0        NaN       9.0     NaN       8.5         NaN
# 4         NaN       9.0        NaN       9.0     NaN       7.4         NaN
# ...       ...       ...        ...       ...     ...       ...         ...
# 70676     0.0       NaN        NaN       9.0     NaN      13.7         NaN
# 70677     NaN       9.0        NaN       9.0     NaN      12.5         NaN
# 70678     NaN       9.0        NaN       9.0     NaN      11.3         NaN
# 70679     NaN       9.0        NaN       9.0     NaN      10.8         NaN
# 70680     NaN       9.0        NaN       9.0     NaN      10.6         NaN
#
# [70681 rows x 24 columns]

# %%
import pandas as pd

# 기상정보
df_weather = pd.read_csv("기상정보.csv",encoding = 'cp949')
df_weather
# Out:
#          지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0        90  속초  2022-05-30 00:00    16.9      NaN      0.4       0.0   83.0
# 1        90  속초  2022-05-30 01:00    16.7      NaN      1.3     320.0   82.0
# 2        90  속초  2022-05-30 02:00    16.8      NaN      0.3       0.0   78.0
# 3        90  속초  2022-05-30 03:00    18.5      NaN      3.4     360.0   73.0
# 4        90  속초  2022-05-30 04:00    17.6      NaN      2.9     360.0   86.0
# ...     ...  ..               ...     ...      ...      ...       ...    ...
# 763881  295  남해  2023-04-29 20:00    15.0      NaN      2.9     290.0   74.0
# 763882  295  남해  2023-04-29 21:00    13.7      NaN      3.4     290.0   71.0
# 763883  295  남해  2023-04-29 22:00    12.6      NaN      3.5     290.0   70.0
# 763884  295  남해  2023-04-29 23:00    11.8      NaN      1.4     250.0   71.0
# 763885  295  남해  2023-04-30 00:00    12.2      NaN      1.1     230.0   68.0
#
#         현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0          1001.2     NaN        NaN     NaN        0.0      16.1
# 1          1000.9     NaN        NaN     NaN        0.0      15.8
# 2          1000.7     NaN        NaN     NaN        0.0      15.4
# 3          1000.7     NaN        NaN     NaN        5.0      16.4
# 4          1001.0     NaN        NaN     NaN        7.0      17.1
# ...           ...     ...        ...     ...        ...       ...
# 763881     1001.9     0.0        NaN     NaN       10.0      15.1
# 763882     1002.7     NaN        NaN     NaN        8.0      13.9
# 763883     1003.3     NaN        NaN     NaN        8.0      12.2
# 763884     1003.6     NaN        NaN     NaN        6.0      11.2
# 763885     1003.9     NaN        NaN     NaN        5.0      10.7
#
# [763886 rows x 14 columns]

# %%
# 기상정보추가

df_weather2 = pd.read_csv("기상정보2.csv",encoding = 'cp949')
df_weather2
# Out:
#          지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0        90  속초  2022-04-01 00:00     3.8      NaN      1.3     270.0   84.0
# 1        90  속초  2022-04-01 01:00     3.4      NaN      1.4     290.0   88.0
# 2        90  속초  2022-04-01 02:00     2.8      NaN      1.7     290.0   86.0
# 3        90  속초  2022-04-01 03:00     2.4      NaN      1.9     290.0   87.0
# 4        90  속초  2022-04-01 04:00     2.9      NaN      1.1     320.0   84.0
# ...     ...  ..               ...     ...      ...      ...       ...    ...
# 134512  295  남해  2022-05-29 19:00    22.0      NaN      1.1     200.0   39.0
# 134513  295  남해  2022-05-29 20:00    21.7      NaN      0.5     180.0   33.0
# 134514  295  남해  2022-05-29 21:00    21.4      NaN      0.9     110.0   45.0
# 134515  295  남해  2022-05-29 22:00    21.1      NaN      1.4     180.0   52.0
# 134516  295  남해  2022-05-29 23:00    20.1      0.0      0.5     160.0   66.0
#
#         현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0          1027.3     NaN        NaN     NaN        5.0       3.9
# 1          1027.7     NaN        NaN     NaN        4.0       3.1
# 2          1027.7     NaN        NaN     NaN        1.0       2.6
# 3          1027.7     NaN        NaN     NaN        0.0       2.3
# 4          1028.1     NaN        NaN     NaN        6.0       2.3
# ...           ...     ...        ...     ...        ...       ...
# 134512      999.6     0.0        NaN     NaN        7.0      27.8
# 134513      999.7     0.0        NaN     NaN        5.0      25.2
# 134514      999.9     NaN        NaN     NaN        0.0      24.3
# 134515     1000.0     NaN        NaN     NaN        2.0      23.8
# 134516      999.6     NaN        NaN     NaN       10.0      22.6
#
# [134517 rows x 14 columns]

# %%
df_weather3 = pd.read_csv("기상정보3.csv",encoding = 'cp949')
df_weather3
# Out:
#        지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0      90  속초  2023-04-29 01:00    16.5      NaN      1.5       340     67
# 1      90  속초  2023-04-29 02:00    16.9      NaN      0.9       320     65
# 2      90  속초  2023-04-29 03:00    15.9      0.0      0.8        20     71
# 3      90  속초  2023-04-29 04:00    14.4      0.3      2.0       360     82
# 4      90  속초  2023-04-29 05:00    12.9      0.1      1.4       340     86
# ...   ...  ..               ...     ...      ...      ...       ...    ...
# 4556  295  남해  2023-04-30 20:00    16.0      NaN      0.5       290     47
# 4557  295  남해  2023-04-30 21:00    15.4      NaN      0.6       250     47
# 4558  295  남해  2023-04-30 22:00    12.8      NaN      0.5       290     61
# 4559  295  남해  2023-04-30 23:00    14.3      NaN      0.3         0     50
# 4560  295  남해  2023-05-01 00:00    15.5      NaN      1.8       290     45
#
#       현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0        1008.2     NaN        NaN     NaN         10      15.3
# 1        1007.6     NaN        NaN     NaN         10      15.2
# 2        1007.0     NaN        NaN     NaN         10      15.1
# 3        1006.3     NaN        NaN     NaN         10      14.5
# 4        1006.2     NaN        NaN     NaN         10      14.1
# ...         ...     ...        ...     ...        ...       ...
# 4556     1006.4     0.0        NaN     NaN          0      13.7
# 4557     1007.4     NaN        NaN     NaN          0      12.5
# 4558     1007.7     NaN        NaN     NaN          0      11.3
# 4559     1007.7     NaN        NaN     NaN          0      10.8
# 4560     1007.8     NaN        NaN     NaN          0      10.6
#
# [4561 rows x 14 columns]

# %%
# 기상정보 병합
df_weather_merge = pd.concat([weather_variable,weather_variable2,weather_variable3])
df_weather_merge
# Out:
#        지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0      90  속초  2022-05-30 00:00    16.9      NaN      0.4       0.0   83.0
# 1      90  속초  2022-05-30 01:00    16.7      NaN      1.3     320.0   82.0
# 2      90  속초  2022-05-30 02:00    16.8      NaN      0.3       0.0   78.0
# 3      90  속초  2022-05-30 03:00    18.5      NaN      3.4     360.0   73.0
# 4      90  속초  2022-05-30 04:00    17.6      NaN      2.9     360.0   86.0
# ...   ...  ..               ...     ...      ...      ...       ...    ...
# 4556  295  남해  2023-04-30 20:00    16.0      NaN      0.5     290.0   47.0
# 4557  295  남해  2023-04-30 21:00    15.4      NaN      0.6     250.0   47.0
# 4558  295  남해  2023-04-30 22:00    12.8      NaN      0.5     290.0   61.0
# 4559  295  남해  2023-04-30 23:00    14.3      NaN      0.3       0.0   50.0
# 4560  295  남해  2023-05-01 00:00    15.5      NaN      1.8     290.0   45.0
#
#       현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0        1001.2     NaN        NaN     NaN        0.0      16.1
# 1        1000.9     NaN        NaN     NaN        0.0      15.8
# 2        1000.7     NaN        NaN     NaN        0.0      15.4
# 3        1000.7     NaN        NaN     NaN        5.0      16.4
# 4        1001.0     NaN        NaN     NaN        7.0      17.1
# ...         ...     ...        ...     ...        ...       ...
# 4556     1006.4     0.0        NaN     NaN        0.0      13.7
# 4557     1007.4     NaN        NaN     NaN        0.0      12.5
# 4558     1007.7     NaN        NaN     NaN        0.0      11.3
# 4559     1007.7     NaN        NaN     NaN        0.0      10.8
# 4560     1007.8     NaN        NaN     NaN        0.0      10.6
#
# [902964 rows x 14 columns]

# %%
# 전력수급자료
power_supply = pd.read_csv("한국전력거래소_5분단위 전력수급현황_20230430.csv",encoding = 'cp949')
power_supply
# Out:
#                     기준일시  공급능력(MW)  현재수요(MW)  최대예측수요(MW)  공급예비력(MW)  \
# 0       2022-04-01 00:00  82494.25  62453.29       70100   20040.96
# 1       2022-04-01 00:05  83807.25  62329.25       70700   21477.99
# 2       2022-04-01 00:10  83799.12  61830.96       70700   21968.15
# 3       2022-04-01 00:15  83790.42  61648.72       70700   22141.69
# 4       2022-04-01 00:20  83770.82  61382.62       70700   22388.19
# ...                  ...       ...       ...         ...        ...
# 113638  2023-04-30 23:35  76101.03  53828.62       57300   22272.40
# 113639  2023-04-30 23:40  76084.24  53693.20       57300   22391.04
# 113640  2023-04-30 23:45  76083.32  52937.98       57300   23145.34
# 113641  2023-04-30 23:50  76077.47  52679.85       57300   23397.62
# 113642  2023-04-30 23:55  76072.29  52671.04       57300   23401.25
#
#         공급예비율(퍼센트)  운영예비력(MW)  운영예비율(퍼센트)
# 0         32.08951    9257.45    14.82300
# 1         34.45893   10889.28    17.47058
# 2         35.52937   10865.86    17.57350
# 3         35.91589   10864.26    17.62284
# 4         36.47318   10451.95    17.02754
# ...            ...        ...         ...
# 113638    41.37651    9389.09    17.44257
# 113639    41.70181    8897.85    16.57166
# 113640    43.72161    9257.95    17.48829
# 113641    44.41474    9303.84    17.66110
# 113642    44.42906    9508.00    18.05166
#
# [113643 rows x 8 columns]

# %% [markdown]
# # 2. 데이터 탐색

# %%
df_weather_merge.head()
# Out:
#    지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0  90  속초  2022-05-30 00:00    16.9      NaN      0.4       0.0   83.0
# 1  90  속초  2022-05-30 01:00    16.7      NaN      1.3     320.0   82.0
# 2  90  속초  2022-05-30 02:00    16.8      NaN      0.3       0.0   78.0
# 3  90  속초  2022-05-30 03:00    18.5      NaN      3.4     360.0   73.0
# 4  90  속초  2022-05-30 04:00    17.6      NaN      2.9     360.0   86.0
#
#    현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0     1001.2     NaN        NaN     NaN        0.0      16.1
# 1     1000.9     NaN        NaN     NaN        0.0      15.8
# 2     1000.7     NaN        NaN     NaN        0.0      15.4
# 3     1000.7     NaN        NaN     NaN        5.0      16.4
# 4     1001.0     NaN        NaN     NaN        7.0      17.1

# %%
# 기상정보 데이터 정보
df_weather_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 902964 entries, 0 to 4560
# Data columns (total 14 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   지점         902964 non-null  int64
#  1   지점명        902964 non-null  object
#  2   일시         902964 non-null  object
#  3   기온(°C)     902263 non-null  float64
#  4   강수량(mm)    76358 non-null   float64
#  5   풍속(m/s)    901045 non-null  float64
#  6   풍향(16방위)   901014 non-null  float64
#  7   습도(%)      901926 non-null  float64
#  8   현지기압(hPa)  902438 non-null  float64
#  9   일조(hr)     495390 non-null  float64
#  10  일사(MJ/m2)  254736 non-null  float64
#  11  적설(cm)     35350 non-null   float64
#  12  전운량(10분위)  900027 non-null  float64
#  13  지면온도(°C)   901115 non-null  float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 103.3+ MB

# %%
# 기상정보 데이터 결측치 
df_weather_merge.isnull().sum()
# Out:
# 지점                0
# 지점명               0
# 일시                0
# 기온(°C)          701
# 강수량(mm)      826606
# 풍속(m/s)        1919
# 풍향(16방위)       1950
# 습도(%)          1038
# 현지기압(hPa)       526
# 일조(hr)       407574
# 일사(MJ/m2)    648228
# 적설(cm)       867614
# 전운량(10분위)      2937
# 지면온도(°C)       1849
# dtype: int64

# %%
df = pd.read_csv("qc플래그.csv",encoding = 'cp949')
df
# Out:
#         지점 지점명                일시  기온 QC플래그  강수량 QC플래그  풍속 QC플래그  풍향 QC플래그  \
# 0       90  속초  2023-06-03 01:00       NaN        NaN       NaN       NaN
# 1       90  속초  2023-06-03 02:00       NaN        NaN       NaN       NaN
# 2       90  속초  2023-06-03 03:00       NaN        NaN       NaN       NaN
# 3       90  속초  2023-06-03 04:00       NaN        NaN       NaN       NaN
# 4       90  속초  2023-06-03 05:00       NaN        NaN       NaN       NaN
# ...    ...  ..               ...       ...        ...       ...       ...
# 50303  295  남해  2023-07-02 20:00       NaN        NaN       NaN       NaN
# 50304  295  남해  2023-07-02 21:00       NaN        NaN       NaN       NaN
# 50305  295  남해  2023-07-02 22:00       NaN        NaN       NaN       NaN
# 50306  295  남해  2023-07-02 23:00       NaN        NaN       NaN       NaN
# 50307  295  남해  2023-07-03 00:00       NaN        NaN       NaN       NaN
#
#        습도 QC플래그  현지기압 QC플래그  일조 QC플래그  일사 QC플래그  지면온도 QC플래그
# 0           NaN         NaN       9.0       9.0         NaN
# 1           NaN         NaN       9.0       9.0         NaN
# 2           NaN         NaN       9.0       9.0         NaN
# 3           NaN         NaN       9.0       9.0         NaN
# 4           NaN         NaN       9.0       9.0         NaN
# ...         ...         ...       ...       ...         ...
# 50303       NaN         NaN       NaN       9.0         NaN
# 50304       NaN         NaN       9.0       9.0         NaN
# 50305       NaN         NaN       9.0       9.0         NaN
# 50306       NaN         NaN       9.0       9.0         NaN
# 50307       NaN         NaN       9.0       9.0         NaN
#
# [50308 rows x 12 columns]

# %% [markdown]
# ## 2. 데이터 탐색

# %%
# 기상변수 데이터를 일시를 기준으로 평균내서 지점 통함

# %% [markdown]
# #### * 기상변수 데이터 구조상 지점별로 데이터가 존재.
# #### * 전력수급자료와 같은 구조를 갖기위해 일시 기준으로 평균을 내서 정리.

# %%
# 기상변수 데이터 탐색 
df_weather_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 902964 entries, 0 to 4560
# Data columns (total 14 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   지점         902964 non-null  int64
#  1   지점명        902964 non-null  object
#  2   일시         902964 non-null  object
#  3   기온(°C)     902263 non-null  float64
#  4   강수량(mm)    76358 non-null   float64
#  5   풍속(m/s)    901045 non-null  float64
#  6   풍향(16방위)   901014 non-null  float64
#  7   습도(%)      901926 non-null  float64
#  8   현지기압(hPa)  902438 non-null  float64
#  9   일조(hr)     495390 non-null  float64
#  10  일사(MJ/m2)  254736 non-null  float64
#  11  적설(cm)     35350 non-null   float64
#  12  전운량(10분위)  900027 non-null  float64
#  13  지면온도(°C)   901115 non-null  float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 103.3+ MB

# %%
df_weather_merge.describe()
# Out:
#                   지점         기온(°C)       강수량(mm)        풍속(m/s)  \
# count  902964.000000  902263.000000  76358.000000  901045.000000
# mean      197.347195      13.548092      1.492983       1.920588
# std        64.344288      10.112576      3.681234       1.764770
# min        90.000000     -24.800000      0.000000       0.000000
# 25%       136.000000       6.100000      0.000000       0.700000
# 50%       202.000000      14.400000      0.200000       1.500000
# 75%       258.000000      21.900000      1.300000       2.700000
# max       295.000000      37.700000     92.200000      36.100000
#
#             풍향(16방위)          습도(%)      현지기압(hPa)         일조(hr)  \
# count  901014.000000  901926.000000  902438.000000  495390.000000
# mean      167.027371      67.988336    1004.271966       0.486352
# std       121.328489      21.989432      16.428102       0.446385
# min         0.000000       2.000000     907.700000       0.000000
# 25%        50.000000      52.000000     998.000000       0.000000
# 50%       180.000000      71.000000    1006.800000       0.500000
# 75%       270.000000      87.000000    1014.700000       1.000000
# max       360.000000     100.000000    1038.100000       1.000000
#
#            일사(MJ/m2)        적설(cm)      전운량(10분위)       지면온도(°C)
# count  254736.000000  35350.000000  900027.000000  901115.000000
# mean        1.162893      5.045417       5.031261      15.882873
# std         1.019094      6.487961       3.931736      12.325992
# min         0.000000      0.000000       0.000000     -20.500000
# 25%         0.230000      1.700000       0.000000       5.900000
# 50%         0.920000      3.600000       6.000000      15.700000
# 75%         1.930000      6.400000       9.000000      24.800000
# max         4.130000     78.400000      10.000000      65.900000

# %%
# 행, 열 개수 
df_ED.shape
# Out:
# (113643, 1)

# %%
# 데이터 정보
df_ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113643 entries, 0 to 113642
# Data columns (total 1 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   현재수요(MW)  113643 non-null  float64
# dtypes: float64(1)
# memory usage: 888.0 KB

# %%
# 결측치 탐색
df_ED.isnull().sum()
# Out:
# 현재수요(MW)    0
# dtype: int64

# %%
import pandas as pd

# 현재수요(MW) 칼럼의 이상치 탐색 함수
def detect_outliers(dataframe, column):
    Q1 = dataframe[column].quantile(0.25)
    Q3 = dataframe[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = dataframe[(dataframe[column] < lower_bound) | (dataframe[column] > upper_bound)]
    return outliers

# 현재수요(MW) 칼럼의 이상치 탐색
outliers = detect_outliers(df_ED, '현재수요(MW)')

# 이상치를 포함한 전체 데이터의 박스플롯 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(df_ED['현재수요(MW)'])
plt.xlabel('현재수요(MW)')
plt.ylabel('값')
plt.title('이상치 탐색 - 현재수요(MW)')
plt.show()

# 이상치를 포함한 데이터의 산점도 그리기
plt.figure(figsize=(8, 6))
plt.scatter(df_ED.index, df_ED['현재수요(MW)'], color='b', label='전체 데이터')
plt.scatter(outliers.index, outliers['현재수요(MW)'], color='r', label='이상치')
plt.xlabel('데이터 인덱스')
plt.ylabel('현재수요(MW)')
plt.title('이상치 탐색 결과')
plt.legend()
plt.show()

# %%
# '현재수요(MW)' 열의 이상치 탐색
outliers = detect_outliers(df_ED, '현재수요(MW)')

# 이상치에 해당하는 행의 인덱스 추출
outlier_indices = outliers.index

print(outlier_indices)
# Out:
# Int64Index([27249, 27250, 27251, 27252, 27253, 27254, 27255, 27256, 27257,
#             27260,
#             ...
#             86705, 86706, 86707, 86708, 86709, 86711, 86712, 86713, 86714,
#             86715],
#            dtype='int64', length=752)

# %%
len(outlier_indices)
# Out:
# 752

# %%
df_ED.loc[86705:86715,:]
# Out:
#        현재수요(MW)
# 86705  89999.12
# 86706  89691.53
# 86707  89509.82
# 86708  89326.10
# 86709  89416.44
# 86710  89207.22
# 86711  89375.37
# 86712  89809.14
# 86713  89495.13
# 86714  89579.14
# 86715  89435.46

# %%
# 이상치가 있는 열 추출
outlier_columns = []
for column in df_ED.columns[1:]:
    outliers = detect_outliers_iqr(df, column)
    if outliers is not None:
        outlier_columns.append(outliers)

# %%
pd.DataFrame(outlier_columns)

# %%
print(outlier_columns)

# %%
df_ED.columns[1:]
# Out:
# Index(['공급능력(MW)', '현재수요(MW)', '최대예측수요(MW)', '공급예비력(MW)', '공급예비율(퍼센트)',
#        '운영예비력(MW)', '운영예비율(퍼센트)'],
#       dtype='object')

# %%
list(df_ED.columns)
# Out:
# ['기준일시',
#  '공급능력(MW)',
#  '현재수요(MW)',
#  '최대예측수요(MW)',
#  '공급예비력(MW)',
#  '공급예비율(퍼센트)',
#  '운영예비력(MW)',
#  '운영예비율(퍼센트)']

# %%
# 예측해야한 기간(2023-03-13'~'2023-03-19') 탐색
df['기준일시'] = pd.to_datetime(df['기준일시'])
df.set_index('기준일시', inplace=True)
range_of_values = df.loc['2023-03-13':'2023-03-19']
pd.DataFrame(range_of_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 예측해야한 기간(2023-03-13'~'2023-03-19') 탐색
# ----> 2 df['기준일시'] = pd.to_datetime(df['기준일시'])
#       3 df.set_index('기준일시', inplace=True)
#       4 range_of_values = df.loc['2023-03-13':'2023-03-19']
#
# NameError: name 'df' is not defined

# %%
# 시각화
import matplotlib.pyplot as plt

# 한글폰트설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 예측해야할 그래프 모형
plt.plot(range_of_values.index, range_of_values['현재수요(MW)'])
plt.xlabel('기준일시')
plt.ylabel('현재수요(MW)')
plt.title('전력수요량 2023-03-13 to 2023-03-19')
plt.xticks(rotation=45)
plt.show()

# %%
df_c = df2 = pd.read_csv("추가자료.csv",encoding = 'cp949')
df_c
# Out:
#        지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0      90  속초  2023-04-29 01:00    16.5      NaN      1.5       340     67
# 1      90  속초  2023-04-29 02:00    16.9      NaN      0.9       320     65
# 2      90  속초  2023-04-29 03:00    15.9      0.0      0.8        20     71
# 3      90  속초  2023-04-29 04:00    14.4      0.3      2.0       360     82
# 4      90  속초  2023-04-29 05:00    12.9      0.1      1.4       340     86
# ...   ...  ..               ...     ...      ...      ...       ...    ...
# 4556  295  남해  2023-04-30 20:00    16.0      NaN      0.5       290     47
# 4557  295  남해  2023-04-30 21:00    15.4      NaN      0.6       250     47
# 4558  295  남해  2023-04-30 22:00    12.8      NaN      0.5       290     61
# 4559  295  남해  2023-04-30 23:00    14.3      NaN      0.3         0     50
# 4560  295  남해  2023-05-01 00:00    15.5      NaN      1.8       290     45
#
#       현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0        1008.2     NaN        NaN     NaN         10      15.3
# 1        1007.6     NaN        NaN     NaN         10      15.2
# 2        1007.0     NaN        NaN     NaN         10      15.1
# 3        1006.3     NaN        NaN     NaN         10      14.5
# 4        1006.2     NaN        NaN     NaN         10      14.1
# ...         ...     ...        ...     ...        ...       ...
# 4556     1006.4     0.0        NaN     NaN          0      13.7
# 4557     1007.4     NaN        NaN     NaN          0      12.5
# 4558     1007.7     NaN        NaN     NaN          0      11.3
# 4559     1007.7     NaN        NaN     NaN          0      10.8
# 4560     1007.8     NaN        NaN     NaN          0      10.6
#
# [4561 rows x 14 columns]

# %%
df_c['일시'] = pd.to_datetime(df_c['일시'])
df_c
# Out:
#        지점 지점명                  일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0      90  속초 2023-04-29 01:00:00    16.5      NaN      1.5       340     67
# 1      90  속초 2023-04-29 02:00:00    16.9      NaN      0.9       320     65
# 2      90  속초 2023-04-29 03:00:00    15.9      0.0      0.8        20     71
# 3      90  속초 2023-04-29 04:00:00    14.4      0.3      2.0       360     82
# 4      90  속초 2023-04-29 05:00:00    12.9      0.1      1.4       340     86
# ...   ...  ..                 ...     ...      ...      ...       ...    ...
# 4556  295  남해 2023-04-30 20:00:00    16.0      NaN      0.5       290     47
# 4557  295  남해 2023-04-30 21:00:00    15.4      NaN      0.6       250     47
# 4558  295  남해 2023-04-30 22:00:00    12.8      NaN      0.5       290     61
# 4559  295  남해 2023-04-30 23:00:00    14.3      NaN      0.3         0     50
# 4560  295  남해 2023-05-01 00:00:00    15.5      NaN      1.8       290     45
#
#       현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0        1008.2     NaN        NaN     NaN         10      15.3
# 1        1007.6     NaN        NaN     NaN         10      15.2
# 2        1007.0     NaN        NaN     NaN         10      15.1
# 3        1006.3     NaN        NaN     NaN         10      14.5
# 4        1006.2     NaN        NaN     NaN         10      14.1
# ...         ...     ...        ...     ...        ...       ...
# 4556     1006.4     0.0        NaN     NaN          0      13.7
# 4557     1007.4     NaN        NaN     NaN          0      12.5
# 4558     1007.7     NaN        NaN     NaN          0      11.3
# 4559     1007.7     NaN        NaN     NaN          0      10.8
# 4560     1007.8     NaN        NaN     NaN          0      10.6
#
# [4561 rows x 14 columns]

# %%
# 특정 일자 범위 추출 
start_date = '2023-04-30'
end_date = '2023-05-01'
filtered_df = df_c[(df_c['일시'] >= start_date) & (df_c['일시'] <= end_date)]
filtered_df
# Out:
#        지점 지점명                  일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 23     90  속초 2023-04-30 00:00:00    12.8      NaN      2.3       290     57
# 24     90  속초 2023-04-30 01:00:00    12.5      NaN      2.7       270     57
# 25     90  속초 2023-04-30 02:00:00    12.4      NaN      1.4       270     53
# 26     90  속초 2023-04-30 03:00:00    12.0      NaN      0.8       200     50
# 27     90  속초 2023-04-30 04:00:00    12.5      NaN      3.3       270     43
# ...   ...  ..                 ...     ...      ...      ...       ...    ...
# 4556  295  남해 2023-04-30 20:00:00    16.0      NaN      0.5       290     47
# 4557  295  남해 2023-04-30 21:00:00    15.4      NaN      0.6       250     47
# 4558  295  남해 2023-04-30 22:00:00    12.8      NaN      0.5       290     61
# 4559  295  남해 2023-04-30 23:00:00    14.3      NaN      0.3         0     50
# 4560  295  남해 2023-05-01 00:00:00    15.5      NaN      1.8       290     45
#
#       현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 23       1001.0     NaN        NaN     NaN          7      11.1
# 24       1000.7     NaN        NaN     NaN          6      10.9
# 25       1000.4     NaN        NaN     NaN          1      10.0
# 26       1000.4     NaN        NaN     NaN          0       9.2
# 27       1000.3     NaN        NaN     NaN          0       8.8
# ...         ...     ...        ...     ...        ...       ...
# 4556     1006.4     0.0        NaN     NaN          0      13.7
# 4557     1007.4     NaN        NaN     NaN          0      12.5
# 4558     1007.7     NaN        NaN     NaN          0      11.3
# 4559     1007.7     NaN        NaN     NaN          0      10.8
# 4560     1007.8     NaN        NaN     NaN          0      10.6
#
# [2376 rows x 14 columns]

# %%
df2 = pd.read_csv("기상변수.csv",encoding = 'cp949')
df2
# Out:
#          지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0        90  속초  2022-05-30 00:00    16.9      NaN      0.4       0.0   83.0
# 1        90  속초  2022-05-30 01:00    16.7      NaN      1.3     320.0   82.0
# 2        90  속초  2022-05-30 02:00    16.8      NaN      0.3       0.0   78.0
# 3        90  속초  2022-05-30 03:00    18.5      NaN      3.4     360.0   73.0
# 4        90  속초  2022-05-30 04:00    17.6      NaN      2.9     360.0   86.0
# ...     ...  ..               ...     ...      ...      ...       ...    ...
# 763881  295  남해  2023-04-29 20:00    15.0      NaN      2.9     290.0   74.0
# 763882  295  남해  2023-04-29 21:00    13.7      NaN      3.4     290.0   71.0
# 763883  295  남해  2023-04-29 22:00    12.6      NaN      3.5     290.0   70.0
# 763884  295  남해  2023-04-29 23:00    11.8      NaN      1.4     250.0   71.0
# 763885  295  남해  2023-04-30 00:00    12.2      NaN      1.1     230.0   68.0
#
#         현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0          1001.2     NaN        NaN     NaN        0.0      16.1
# 1          1000.9     NaN        NaN     NaN        0.0      15.8
# 2          1000.7     NaN        NaN     NaN        0.0      15.4
# 3          1000.7     NaN        NaN     NaN        5.0      16.4
# 4          1001.0     NaN        NaN     NaN        7.0      17.1
# ...           ...     ...        ...     ...        ...       ...
# 763881     1001.9     0.0        NaN     NaN       10.0      15.1
# 763882     1002.7     NaN        NaN     NaN        8.0      13.9
# 763883     1003.3     NaN        NaN     NaN        8.0      12.2
# 763884     1003.6     NaN        NaN     NaN        6.0      11.2
# 763885     1003.9     NaN        NaN     NaN        5.0      10.7
#
# [763886 rows x 14 columns]

# %%
df3 = pd.read_csv("기상변수2.csv",encoding = 'cp949')
df3
# Out:
#          지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0        90  속초  2022-04-01 00:00     3.8      NaN      1.3     270.0   84.0
# 1        90  속초  2022-04-01 01:00     3.4      NaN      1.4     290.0   88.0
# 2        90  속초  2022-04-01 02:00     2.8      NaN      1.7     290.0   86.0
# 3        90  속초  2022-04-01 03:00     2.4      NaN      1.9     290.0   87.0
# 4        90  속초  2022-04-01 04:00     2.9      NaN      1.1     320.0   84.0
# ...     ...  ..               ...     ...      ...      ...       ...    ...
# 134512  295  남해  2022-05-29 19:00    22.0      NaN      1.1     200.0   39.0
# 134513  295  남해  2022-05-29 20:00    21.7      NaN      0.5     180.0   33.0
# 134514  295  남해  2022-05-29 21:00    21.4      NaN      0.9     110.0   45.0
# 134515  295  남해  2022-05-29 22:00    21.1      NaN      1.4     180.0   52.0
# 134516  295  남해  2022-05-29 23:00    20.1      0.0      0.5     160.0   66.0
#
#         현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0          1027.3     NaN        NaN     NaN        5.0       3.9
# 1          1027.7     NaN        NaN     NaN        4.0       3.1
# 2          1027.7     NaN        NaN     NaN        1.0       2.6
# 3          1027.7     NaN        NaN     NaN        0.0       2.3
# 4          1028.1     NaN        NaN     NaN        6.0       2.3
# ...           ...     ...        ...     ...        ...       ...
# 134512      999.6     0.0        NaN     NaN        7.0      27.8
# 134513      999.7     0.0        NaN     NaN        5.0      25.2
# 134514      999.9     NaN        NaN     NaN        0.0      24.3
# 134515     1000.0     NaN        NaN     NaN        2.0      23.8
# 134516      999.6     NaN        NaN     NaN       10.0      22.6
#
# [134517 rows x 14 columns]

# %%
df4 = pd.concat([df2,df3,filtered_df])
df4
# Out:
#        지점 지점명                   일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0      90  속초     2022-05-30 00:00    16.9      NaN      0.4       0.0   83.0
# 1      90  속초     2022-05-30 01:00    16.7      NaN      1.3     320.0   82.0
# 2      90  속초     2022-05-30 02:00    16.8      NaN      0.3       0.0   78.0
# 3      90  속초     2022-05-30 03:00    18.5      NaN      3.4     360.0   73.0
# 4      90  속초     2022-05-30 04:00    17.6      NaN      2.9     360.0   86.0
# ...   ...  ..                  ...     ...      ...      ...       ...    ...
# 4556  295  남해  2023-04-30 20:00:00    16.0      NaN      0.5     290.0   47.0
# 4557  295  남해  2023-04-30 21:00:00    15.4      NaN      0.6     250.0   47.0
# 4558  295  남해  2023-04-30 22:00:00    12.8      NaN      0.5     290.0   61.0
# 4559  295  남해  2023-04-30 23:00:00    14.3      NaN      0.3       0.0   50.0
# 4560  295  남해  2023-05-01 00:00:00    15.5      NaN      1.8     290.0   45.0
#
#       현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0        1001.2     NaN        NaN     NaN        0.0      16.1
# 1        1000.9     NaN        NaN     NaN        0.0      15.8
# 2        1000.7     NaN        NaN     NaN        0.0      15.4
# 3        1000.7     NaN        NaN     NaN        5.0      16.4
# 4        1001.0     NaN        NaN     NaN        7.0      17.1
# ...         ...     ...        ...     ...        ...       ...
# 4556     1006.4     0.0        NaN     NaN        0.0      13.7
# 4557     1007.4     NaN        NaN     NaN        0.0      12.5
# 4558     1007.7     NaN        NaN     NaN        0.0      11.3
# 4559     1007.7     NaN        NaN     NaN        0.0      10.8
# 4560     1007.8     NaN        NaN     NaN        0.0      10.6
#
# [900779 rows x 14 columns]

# %%
df4 = df4.reset_index(drop=True)
df4
# Out:
#          지점 지점명                   일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  \
# 0        90  속초     2022-05-30 00:00    16.9      NaN      0.4       0.0
# 1        90  속초     2022-05-30 01:00    16.7      NaN      1.3     320.0
# 2        90  속초     2022-05-30 02:00    16.8      NaN      0.3       0.0
# 3        90  속초     2022-05-30 03:00    18.5      NaN      3.4     360.0
# 4        90  속초     2022-05-30 04:00    17.6      NaN      2.9     360.0
# ...     ...  ..                  ...     ...      ...      ...       ...
# 900774  295  남해  2023-04-30 20:00:00    16.0      NaN      0.5     290.0
# 900775  295  남해  2023-04-30 21:00:00    15.4      NaN      0.6     250.0
# 900776  295  남해  2023-04-30 22:00:00    12.8      NaN      0.5     290.0
# 900777  295  남해  2023-04-30 23:00:00    14.3      NaN      0.3       0.0
# 900778  295  남해  2023-05-01 00:00:00    15.5      NaN      1.8     290.0
#
#         습도(%)  현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0        83.0     1001.2     NaN        NaN     NaN        0.0      16.1
# 1        82.0     1000.9     NaN        NaN     NaN        0.0      15.8
# 2        78.0     1000.7     NaN        NaN     NaN        0.0      15.4
# 3        73.0     1000.7     NaN        NaN     NaN        5.0      16.4
# 4        86.0     1001.0     NaN        NaN     NaN        7.0      17.1
# ...       ...        ...     ...        ...     ...        ...       ...
# 900774   47.0     1006.4     0.0        NaN     NaN        0.0      13.7
# 900775   47.0     1007.4     NaN        NaN     NaN        0.0      12.5
# 900776   61.0     1007.7     NaN        NaN     NaN        0.0      11.3
# 900777   50.0     1007.7     NaN        NaN     NaN        0.0      10.8
# 900778   45.0     1007.8     NaN        NaN     NaN        0.0      10.6
#
# [900779 rows x 14 columns]

# %%
df4 = df4.drop(['지점','지점명'], axis=1)
df4
# Out:
#                          일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0          2022-05-30 00:00    16.9      NaN      0.4       0.0   83.0
# 1          2022-05-30 01:00    16.7      NaN      1.3     320.0   82.0
# 2          2022-05-30 02:00    16.8      NaN      0.3       0.0   78.0
# 3          2022-05-30 03:00    18.5      NaN      3.4     360.0   73.0
# 4          2022-05-30 04:00    17.6      NaN      2.9     360.0   86.0
# ...                     ...     ...      ...      ...       ...    ...
# 900774  2023-04-30 20:00:00    16.0      NaN      0.5     290.0   47.0
# 900775  2023-04-30 21:00:00    15.4      NaN      0.6     250.0   47.0
# 900776  2023-04-30 22:00:00    12.8      NaN      0.5     290.0   61.0
# 900777  2023-04-30 23:00:00    14.3      NaN      0.3       0.0   50.0
# 900778  2023-05-01 00:00:00    15.5      NaN      1.8     290.0   45.0
#
#         현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0          1001.2     NaN        NaN     NaN        0.0      16.1
# 1          1000.9     NaN        NaN     NaN        0.0      15.8
# 2          1000.7     NaN        NaN     NaN        0.0      15.4
# 3          1000.7     NaN        NaN     NaN        5.0      16.4
# 4          1001.0     NaN        NaN     NaN        7.0      17.1
# ...           ...     ...        ...     ...        ...       ...
# 900774     1006.4     0.0        NaN     NaN        0.0      13.7
# 900775     1007.4     NaN        NaN     NaN        0.0      12.5
# 900776     1007.7     NaN        NaN     NaN        0.0      11.3
# 900777     1007.7     NaN        NaN     NaN        0.0      10.8
# 900778     1007.8     NaN        NaN     NaN        0.0      10.6
#
# [900779 rows x 12 columns]

# %%
df4
# Out:
#                          일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0          2022-05-30 00:00    16.9      NaN      0.4       0.0   83.0
# 1          2022-05-30 01:00    16.7      NaN      1.3     320.0   82.0
# 2          2022-05-30 02:00    16.8      NaN      0.3       0.0   78.0
# 3          2022-05-30 03:00    18.5      NaN      3.4     360.0   73.0
# 4          2022-05-30 04:00    17.6      NaN      2.9     360.0   86.0
# ...                     ...     ...      ...      ...       ...    ...
# 900774  2023-04-30 20:00:00    16.0      NaN      0.5     290.0   47.0
# 900775  2023-04-30 21:00:00    15.4      NaN      0.6     250.0   47.0
# 900776  2023-04-30 22:00:00    12.8      NaN      0.5     290.0   61.0
# 900777  2023-04-30 23:00:00    14.3      NaN      0.3       0.0   50.0
# 900778  2023-05-01 00:00:00    15.5      NaN      1.8     290.0   45.0
#
#         현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0          1001.2     NaN        NaN     NaN        0.0      16.1
# 1          1000.9     NaN        NaN     NaN        0.0      15.8
# 2          1000.7     NaN        NaN     NaN        0.0      15.4
# 3          1000.7     NaN        NaN     NaN        5.0      16.4
# 4          1001.0     NaN        NaN     NaN        7.0      17.1
# ...           ...     ...        ...     ...        ...       ...
# 900774     1006.4     0.0        NaN     NaN        0.0      13.7
# 900775     1007.4     NaN        NaN     NaN        0.0      12.5
# 900776     1007.7     NaN        NaN     NaN        0.0      11.3
# 900777     1007.7     NaN        NaN     NaN        0.0      10.8
# 900778     1007.8     NaN        NaN     NaN        0.0      10.6
#
# [900779 rows x 12 columns]

# %%
df4[df4['일시']=='2022-05-30 00:00']
# Out:
#                       일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0       2022-05-30 00:00    16.9      NaN      0.4       0.0   83.0
# 8041    2022-05-30 00:00    17.3      NaN      0.0       0.0   83.0
# 16082   2022-05-30 00:00    17.3      NaN      0.8     140.0  100.0
# 24123   2022-05-30 00:00    17.7      NaN      0.0       0.0   91.0
# 32164   2022-05-30 00:00    16.5      NaN      0.3       0.0   98.0
# ...                  ...     ...      ...      ...       ...    ...
# 723681  2022-05-30 00:00    22.0      NaN      0.0       0.0   49.0
# 731722  2022-05-30 00:00    22.6      0.0      0.2       0.0   39.0
# 739763  2022-05-30 00:00    20.7      NaN      3.9      50.0   60.0
# 747804  2022-05-30 00:00    20.8      NaN      0.4       0.0   52.0
# 755845  2022-05-30 00:00    20.0      0.0      0.4       0.0   68.0
#
#         현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  지면온도(°C)
# 0          1001.2     NaN        NaN     NaN        0.0      16.1
# 8041        992.8     NaN        NaN     NaN        0.0      16.8
# 16082       986.4     NaN        NaN     NaN        0.0      16.5
# 24123       990.5     NaN        NaN     NaN        2.0      17.2
# 32164      1001.2     NaN        NaN     NaN        4.0      16.5
# ...           ...     ...        ...     ...        ...       ...
# 723681     1000.8     NaN        NaN     NaN        4.0      24.5
# 731722     1003.1     NaN        NaN     NaN       10.0      22.0
# 739763      988.9     NaN        NaN     NaN        0.0      22.1
# 747804      999.6     NaN        NaN     NaN        9.0      22.1
# 755845      999.1     NaN        NaN     NaN        6.0      22.5
#
# [95 rows x 12 columns]

# %%
df4['일시'] = pd.to_datetime(df4['일시'])

# %%
# 일시별 나머지`b 열들의 평균값 계산
mean_df = df4.groupby('일시').mean()

# %%
mean_df
# Out:
#                         기온(°C)   강수량(mm)   풍속(m/s)    풍향(16방위)      습도(%)  \
# 일시
# 2022-04-01 00:00:00   6.180000  0.528571  1.849474  172.000000  81.884211
# 2022-04-01 01:00:00   5.684211  0.144444  1.745263  156.631579  83.148421
# 2022-04-01 02:00:00   5.257895  0.933333  1.561053  150.000000  84.505263
# 2022-04-01 03:00:00   4.855789  0.250000  1.535789  140.631579  85.042105
# 2022-04-01 04:00:00   4.486316       NaN  1.573684  138.526316  85.557895
# ...                        ...       ...       ...         ...        ...
# 2023-04-30 20:00:00  14.831579  0.000000  2.283158  220.000000  54.315789
# 2023-04-30 21:00:00  13.886316  0.025000  2.096842  213.263158  58.968421
# 2023-04-30 22:00:00  13.172632  0.066667  2.020000  203.894737  61.873684
# 2023-04-30 23:00:00  12.472632  0.180000  1.834737  188.947368  65.273684
# 2023-05-01 00:00:00  11.940625  0.550000  2.023958  200.937500  68.208333
#
#                        현지기압(hPa)    일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  \
# 일시
# 2022-04-01 00:00:00  1015.023158       NaN        NaN     0.4   6.553191
# 2022-04-01 01:00:00  1015.344211       NaN        NaN     0.5   7.053191
# 2022-04-01 02:00:00  1015.386316       NaN        NaN     0.6   7.393617
# 2022-04-01 03:00:00  1015.292632       NaN        NaN     0.6   6.223404
# 2022-04-01 04:00:00  1015.402105       NaN        NaN     0.6   5.106383
# ...                          ...       ...        ...     ...        ...
# 2023-04-30 20:00:00   998.632632  0.002105   0.006667     NaN   2.378947
# 2023-04-30 21:00:00   999.383158       NaN        NaN     NaN   2.221053
# 2023-04-30 22:00:00   999.905263       NaN        NaN     0.1   2.536842
# 2023-04-30 23:00:00   999.965263       NaN        NaN     NaN   2.831579
# 2023-05-01 00:00:00  1000.364583       NaN        NaN     NaN   3.041667
#
#                       지면온도(°C)
# 일시
# 2022-04-01 00:00:00   6.186316
# 2022-04-01 01:00:00   5.702105
# 2022-04-01 02:00:00   5.307368
# 2022-04-01 03:00:00   4.801053
# 2022-04-01 04:00:00   4.322105
# ...                        ...
# 2023-04-30 20:00:00  13.493684
# 2023-04-30 21:00:00  12.431579
# 2023-04-30 22:00:00  11.664211
# 2023-04-30 23:00:00  11.103158
# 2023-05-01 00:00:00  10.662500
#
# [9481 rows x 11 columns]

# %%
# 5분 단위로 보간(interpolation)
df_interpolated = mean_df.resample('5T').interpolate()

# %%
df_interpolated
# Out:
#                         기온(°C)   강수량(mm)   풍속(m/s)    풍향(16방위)      습도(%)  \
# 일시
# 2022-04-01 00:00:00   6.180000  0.528571  1.849474  172.000000  81.884211
# 2022-04-01 00:05:00   6.138684  0.496561  1.840789  170.719298  81.989561
# 2022-04-01 00:10:00   6.097368  0.464550  1.832105  169.438596  82.094912
# 2022-04-01 00:15:00   6.056053  0.432540  1.823421  168.157895  82.200263
# 2022-04-01 00:20:00   6.014737  0.400529  1.814737  166.877193  82.305614
# ...                        ...       ...       ...         ...        ...
# 2023-04-30 23:40:00  12.117961  0.426667  1.960885  196.940789  67.230117
# 2023-04-30 23:45:00  12.073627  0.457500  1.976653  197.939967  67.474671
# 2023-04-30 23:50:00  12.029293  0.488333  1.992421  198.939145  67.719225
# 2023-04-30 23:55:00  11.984959  0.519167  2.008190  199.938322  67.963779
# 2023-05-01 00:00:00  11.940625  0.550000  2.023958  200.937500  68.208333
#
#                        현지기압(hPa)    일조(hr)  일사(MJ/m2)    적설(cm)  전운량(10분위)  \
# 일시
# 2022-04-01 00:00:00  1015.023158       NaN        NaN  0.400000   6.553191
# 2022-04-01 00:05:00  1015.049912       NaN        NaN  0.408333   6.594858
# 2022-04-01 00:10:00  1015.076667       NaN        NaN  0.416667   6.636525
# 2022-04-01 00:15:00  1015.103421       NaN        NaN  0.425000   6.678191
# 2022-04-01 00:20:00  1015.130175       NaN        NaN  0.433333   6.719858
# ...                          ...       ...        ...       ...        ...
# 2023-04-30 23:40:00  1000.231477  0.002105   0.006667  0.100000   2.971637
# 2023-04-30 23:45:00  1000.264753  0.002105   0.006667  0.100000   2.989145
# 2023-04-30 23:50:00  1000.298030  0.002105   0.006667  0.100000   3.006652
# 2023-04-30 23:55:00  1000.331307  0.002105   0.006667  0.100000   3.024159
# 2023-05-01 00:00:00  1000.364583  0.002105   0.006667  0.100000   3.041667
#
#                       지면온도(°C)
# 일시
# 2022-04-01 00:00:00   6.186316
# 2022-04-01 00:05:00   6.145965
# 2022-04-01 00:10:00   6.105614
# 2022-04-01 00:15:00   6.065263
# 2022-04-01 00:20:00   6.024912
# ...                        ...
# 2023-04-30 23:40:00  10.809386
# 2023-04-30 23:45:00  10.772664
# 2023-04-30 23:50:00  10.735943
# 2023-04-30 23:55:00  10.699221
# 2023-05-01 00:00:00  10.662500
#
# [113761 rows x 11 columns]

# %%
df_interpolated  = df_interpolated .drop(df_interpolated .index[-1])
df_interpolated
# Out:
#                         기온(°C)   강수량(mm)   풍속(m/s)    풍향(16방위)      습도(%)  \
# 일시
# 2022-04-01 00:00:00   6.180000  0.528571  1.849474  172.000000  81.884211
# 2022-04-01 00:05:00   6.138684  0.496561  1.840789  170.719298  81.989561
# 2022-04-01 00:10:00   6.097368  0.464550  1.832105  169.438596  82.094912
# 2022-04-01 00:15:00   6.056053  0.432540  1.823421  168.157895  82.200263
# 2022-04-01 00:20:00   6.014737  0.400529  1.814737  166.877193  82.305614
# ...                        ...       ...       ...         ...        ...
# 2023-04-30 23:35:00  12.162294  0.395833  1.945116  195.941612  66.985563
# 2023-04-30 23:40:00  12.117961  0.426667  1.960885  196.940789  67.230117
# 2023-04-30 23:45:00  12.073627  0.457500  1.976653  197.939967  67.474671
# 2023-04-30 23:50:00  12.029293  0.488333  1.992421  198.939145  67.719225
# 2023-04-30 23:55:00  11.984959  0.519167  2.008190  199.938322  67.963779
#
#                        현지기압(hPa)    일조(hr)  일사(MJ/m2)    적설(cm)  전운량(10분위)  \
# 일시
# 2022-04-01 00:00:00  1015.023158       NaN        NaN  0.400000   6.553191
# 2022-04-01 00:05:00  1015.049912       NaN        NaN  0.408333   6.594858
# 2022-04-01 00:10:00  1015.076667       NaN        NaN  0.416667   6.636525
# 2022-04-01 00:15:00  1015.103421       NaN        NaN  0.425000   6.678191
# 2022-04-01 00:20:00  1015.130175       NaN        NaN  0.433333   6.719858
# ...                          ...       ...        ...       ...        ...
# 2023-04-30 23:35:00  1000.198200  0.002105   0.006667  0.100000   2.954130
# 2023-04-30 23:40:00  1000.231477  0.002105   0.006667  0.100000   2.971637
# 2023-04-30 23:45:00  1000.264753  0.002105   0.006667  0.100000   2.989145
# 2023-04-30 23:50:00  1000.298030  0.002105   0.006667  0.100000   3.006652
# 2023-04-30 23:55:00  1000.331307  0.002105   0.006667  0.100000   3.024159
#
#                       지면온도(°C)
# 일시
# 2022-04-01 00:00:00   6.186316
# 2022-04-01 00:05:00   6.145965
# 2022-04-01 00:10:00   6.105614
# 2022-04-01 00:15:00   6.065263
# 2022-04-01 00:20:00   6.024912
# ...                        ...
# 2023-04-30 23:35:00  10.846107
# 2023-04-30 23:40:00  10.809386
# 2023-04-30 23:45:00  10.772664
# 2023-04-30 23:50:00  10.735943
# 2023-04-30 23:55:00  10.699221
#
# [113760 rows x 11 columns]

# %%
df
# Out:
#                      공급능력(MW)  현재수요(MW)  최대예측수요(MW)  공급예비력(MW)  공급예비율(퍼센트)  \
# 기준일시
# 2022-04-01 00:00:00  82494.25  62453.29       70100   20040.96    32.08951
# 2022-04-01 00:05:00  83807.25  62329.25       70700   21477.99    34.45893
# 2022-04-01 00:10:00  83799.12  61830.96       70700   21968.15    35.52937
# 2022-04-01 00:15:00  83790.42  61648.72       70700   22141.69    35.91589
# 2022-04-01 00:20:00  83770.82  61382.62       70700   22388.19    36.47318
# ...                       ...       ...         ...        ...         ...
# 2023-04-30 23:35:00  76101.03  53828.62       57300   22272.40    41.37651
# 2023-04-30 23:40:00  76084.24  53693.20       57300   22391.04    41.70181
# 2023-04-30 23:45:00  76083.32  52937.98       57300   23145.34    43.72161
# 2023-04-30 23:50:00  76077.47  52679.85       57300   23397.62    44.41474
# 2023-04-30 23:55:00  76072.29  52671.04       57300   23401.25    44.42906
#
#                      운영예비력(MW)  운영예비율(퍼센트)
# 기준일시
# 2022-04-01 00:00:00    9257.45    14.82300
# 2022-04-01 00:05:00   10889.28    17.47058
# 2022-04-01 00:10:00   10865.86    17.57350
# 2022-04-01 00:15:00   10864.26    17.62284
# 2022-04-01 00:20:00   10451.95    17.02754
# ...                        ...         ...
# 2023-04-30 23:35:00    9389.09    17.44257
# 2023-04-30 23:40:00    8897.85    16.57166
# 2023-04-30 23:45:00    9257.95    17.48829
# 2023-04-30 23:50:00    9303.84    17.66110
# 2023-04-30 23:55:00    9508.00    18.05166
#
# [113643 rows x 7 columns]

# %%
df.loc['2022-04-01 00:00:00']
# Out:
# 공급능력(MW)      82494.25000
# 현재수요(MW)      62453.29000
# 최대예측수요(MW)    70100.00000
# 공급예비력(MW)     20040.96000
# 공급예비율(퍼센트)       32.08951
# 운영예비력(MW)      9257.45000
# 운영예비율(퍼센트)       14.82300
# Name: 2022-04-01 00:00:00, dtype: float64

# %%
# 인덱스 기준으로 교집합 데이터프레임 생성
intersection_df = pd.merge(df_interpolated, df, left_index=True, right_index=True)

# 결과 출력
intersection_df = pd.DataFrame(intersection_df)
intersection_df
# Out:
#                         기온(°C)   강수량(mm)   풍속(m/s)    풍향(16방위)      습도(%)  \
# 2022-04-01 00:00:00   6.180000  0.528571  1.849474  172.000000  81.884211
# 2022-04-01 00:05:00   6.138684  0.496561  1.840789  170.719298  81.989561
# 2022-04-01 00:10:00   6.097368  0.464550  1.832105  169.438596  82.094912
# 2022-04-01 00:15:00   6.056053  0.432540  1.823421  168.157895  82.200263
# 2022-04-01 00:20:00   6.014737  0.400529  1.814737  166.877193  82.305614
# ...                        ...       ...       ...         ...        ...
# 2023-04-30 23:35:00  12.162294  0.395833  1.945116  195.941612  66.985563
# 2023-04-30 23:40:00  12.117961  0.426667  1.960885  196.940789  67.230117
# 2023-04-30 23:45:00  12.073627  0.457500  1.976653  197.939967  67.474671
# 2023-04-30 23:50:00  12.029293  0.488333  1.992421  198.939145  67.719225
# 2023-04-30 23:55:00  11.984959  0.519167  2.008190  199.938322  67.963779
#
#                        현지기압(hPa)    일조(hr)  일사(MJ/m2)    적설(cm)  전운량(10분위)  \
# 2022-04-01 00:00:00  1015.023158       NaN        NaN  0.400000   6.553191
# 2022-04-01 00:05:00  1015.049912       NaN        NaN  0.408333   6.594858
# 2022-04-01 00:10:00  1015.076667       NaN        NaN  0.416667   6.636525
# 2022-04-01 00:15:00  1015.103421       NaN        NaN  0.425000   6.678191
# 2022-04-01 00:20:00  1015.130175       NaN        NaN  0.433333   6.719858
# ...                          ...       ...        ...       ...        ...
# 2023-04-30 23:35:00  1000.198200  0.002105   0.006667  0.100000   2.954130
# 2023-04-30 23:40:00  1000.231477  0.002105   0.006667  0.100000   2.971637
# 2023-04-30 23:45:00  1000.264753  0.002105   0.006667  0.100000   2.989145
# 2023-04-30 23:50:00  1000.298030  0.002105   0.006667  0.100000   3.006652
# 2023-04-30 23:55:00  1000.331307  0.002105   0.006667  0.100000   3.024159
#
#                       지면온도(°C)  공급능력(MW)  현재수요(MW)  최대예측수요(MW)  공급예비력(MW)  \
# 2022-04-01 00:00:00   6.186316  82494.25  62453.29       70100   20040.96
# 2022-04-01 00:05:00   6.145965  83807.25  62329.25       70700   21477.99
# 2022-04-01 00:10:00   6.105614  83799.12  61830.96       70700   21968.15
# 2022-04-01 00:15:00   6.065263  83790.42  61648.72       70700   22141.69
# 2022-04-01 00:20:00   6.024912  83770.82  61382.62       70700   22388.19
# ...                        ...       ...       ...         ...        ...
# 2023-04-30 23:35:00  10.846107  76101.03  53828.62       57300   22272.40
# 2023-04-30 23:40:00  10.809386  76084.24  53693.20       57300   22391.04
# 2023-04-30 23:45:00  10.772664  76083.32  52937.98       57300   23145.34
# 2023-04-30 23:50:00  10.735943  76077.47  52679.85       57300   23397.62
# 2023-04-30 23:55:00  10.699221  76072.29  52671.04       57300   23401.25
#
#                      공급예비율(퍼센트)  운영예비력(MW)  운영예비율(퍼센트)
# 2022-04-01 00:00:00    32.08951    9257.45    14.82300
# 2022-04-01 00:05:00    34.45893   10889.28    17.47058
# 2022-04-01 00:10:00    35.52937   10865.86    17.57350
# 2022-04-01 00:15:00    35.91589   10864.26    17.62284
# 2022-04-01 00:20:00    36.47318   10451.95    17.02754
# ...                         ...        ...         ...
# 2023-04-30 23:35:00    41.37651    9389.09    17.44257
# 2023-04-30 23:40:00    41.70181    8897.85    16.57166
# 2023-04-30 23:45:00    43.72161    9257.95    17.48829
# 2023-04-30 23:50:00    44.41474    9303.84    17.66110
# 2023-04-30 23:55:00    44.42906    9508.00    18.05166
#
# [113643 rows x 18 columns]

# %%
list(different_values['Values'])
df_interpolated = df_interpolated.drop(list(different_values['Values']))
df_interpolated
# Out:
#                         기온(°C)   강수량(mm)   풍속(m/s)    풍향(16방위)      습도(%)  \
# 일시
# 2022-04-01 00:00:00   6.180000  0.528571  1.849474  172.000000  81.884211
# 2022-04-01 00:05:00   6.138684  0.496561  1.840789  170.719298  81.989561
# 2022-04-01 00:10:00   6.097368  0.464550  1.832105  169.438596  82.094912
# 2022-04-01 00:15:00   6.056053  0.432540  1.823421  168.157895  82.200263
# 2022-04-01 00:20:00   6.014737  0.400529  1.814737  166.877193  82.305614
# ...                        ...       ...       ...         ...        ...
# 2023-04-30 23:35:00  12.162294  0.395833  1.945116  195.941612  66.985563
# 2023-04-30 23:40:00  12.117961  0.426667  1.960885  196.940789  67.230117
# 2023-04-30 23:45:00  12.073627  0.457500  1.976653  197.939967  67.474671
# 2023-04-30 23:50:00  12.029293  0.488333  1.992421  198.939145  67.719225
# 2023-04-30 23:55:00  11.984959  0.519167  2.008190  199.938322  67.963779
#
#                        현지기압(hPa)    일조(hr)  일사(MJ/m2)    적설(cm)  전운량(10분위)  \
# 일시
# 2022-04-01 00:00:00  1015.023158       NaN        NaN  0.400000   6.553191
# 2022-04-01 00:05:00  1015.049912       NaN        NaN  0.408333   6.594858
# 2022-04-01 00:10:00  1015.076667       NaN        NaN  0.416667   6.636525
# 2022-04-01 00:15:00  1015.103421       NaN        NaN  0.425000   6.678191
# 2022-04-01 00:20:00  1015.130175       NaN        NaN  0.433333   6.719858
# ...                          ...       ...        ...       ...        ...
# 2023-04-30 23:35:00  1000.198200  0.002105   0.006667  0.100000   2.954130
# 2023-04-30 23:40:00  1000.231477  0.002105   0.006667  0.100000   2.971637
# 2023-04-30 23:45:00  1000.264753  0.002105   0.006667  0.100000   2.989145
# 2023-04-30 23:50:00  1000.298030  0.002105   0.006667  0.100000   3.006652
# 2023-04-30 23:55:00  1000.331307  0.002105   0.006667  0.100000   3.024159
#
#                       지면온도(°C)
# 일시
# 2022-04-01 00:00:00   6.186316
# 2022-04-01 00:05:00   6.145965
# 2022-04-01 00:10:00   6.105614
# 2022-04-01 00:15:00   6.065263
# 2022-04-01 00:20:00   6.024912
# ...                        ...
# 2023-04-30 23:35:00  10.846107
# 2023-04-30 23:40:00  10.809386
# 2023-04-30 23:45:00  10.772664
# 2023-04-30 23:50:00  10.735943
# 2023-04-30 23:55:00  10.699221
#
# [113643 rows x 11 columns]

# %%
df_ff = df_interpolated[['기온(°C)', '강수량(mm)', '풍속(m/s)', '습도(%)', '일조(hr)', '지면온도(°C)']]
df_ff
# Out:
#                         기온(°C)   강수량(mm)   풍속(m/s)      습도(%)    일조(hr)  \
# 일시
# 2022-04-01 00:00:00   6.180000  0.528571  1.849474  81.884211       NaN
# 2022-04-01 00:05:00   6.138684  0.496561  1.840789  81.989561       NaN
# 2022-04-01 00:10:00   6.097368  0.464550  1.832105  82.094912       NaN
# 2022-04-01 00:15:00   6.056053  0.432540  1.823421  82.200263       NaN
# 2022-04-01 00:20:00   6.014737  0.400529  1.814737  82.305614       NaN
# ...                        ...       ...       ...        ...       ...
# 2023-04-30 23:35:00  12.162294  0.395833  1.945116  66.985563  0.002105
# 2023-04-30 23:40:00  12.117961  0.426667  1.960885  67.230117  0.002105
# 2023-04-30 23:45:00  12.073627  0.457500  1.976653  67.474671  0.002105
# 2023-04-30 23:50:00  12.029293  0.488333  1.992421  67.719225  0.002105
# 2023-04-30 23:55:00  11.984959  0.519167  2.008190  67.963779  0.002105
#
#                       지면온도(°C)
# 일시
# 2022-04-01 00:00:00   6.186316
# 2022-04-01 00:05:00   6.145965
# 2022-04-01 00:10:00   6.105614
# 2022-04-01 00:15:00   6.065263
# 2022-04-01 00:20:00   6.024912
# ...                        ...
# 2023-04-30 23:35:00  10.846107
# 2023-04-30 23:40:00  10.809386
# 2023-04-30 23:45:00  10.772664
# 2023-04-30 23:50:00  10.735943
# 2023-04-30 23:55:00  10.699221
#
# [113643 rows x 6 columns]

# %%
df_fff = pd.DataFrame(df['현재수요(MW)'])
df_fff
# Out:
#                      현재수요(MW)
# 기준일시
# 2022-04-01 00:00:00  62453.29
# 2022-04-01 00:05:00  62329.25
# 2022-04-01 00:10:00  61830.96
# 2022-04-01 00:15:00  61648.72
# 2022-04-01 00:20:00  61382.62
# ...                       ...
# 2023-04-30 23:35:00  53828.62
# 2023-04-30 23:40:00  53693.20
# 2023-04-30 23:45:00  52937.98
# 2023-04-30 23:50:00  52679.85
# 2023-04-30 23:55:00  52671.04
#
# [113643 rows x 1 columns]

# %%
df= df.drop(list(different_values['Values']), errors='ignore')
df
# Out:
#                      공급능력(MW)  현재수요(MW)  최대예측수요(MW)  공급예비력(MW)  공급예비율(퍼센트)  \
# 기준일시
# 2022-04-01 00:00:00  82494.25  62453.29       70100   20040.96    32.08951
# 2022-04-01 00:05:00  83807.25  62329.25       70700   21477.99    34.45893
# 2022-04-01 00:10:00  83799.12  61830.96       70700   21968.15    35.52937
# 2022-04-01 00:15:00  83790.42  61648.72       70700   22141.69    35.91589
# 2022-04-01 00:20:00  83770.82  61382.62       70700   22388.19    36.47318
# ...                       ...       ...         ...        ...         ...
# 2023-04-30 23:35:00  76101.03  53828.62       57300   22272.40    41.37651
# 2023-04-30 23:40:00  76084.24  53693.20       57300   22391.04    41.70181
# 2023-04-30 23:45:00  76083.32  52937.98       57300   23145.34    43.72161
# 2023-04-30 23:50:00  76077.47  52679.85       57300   23397.62    44.41474
# 2023-04-30 23:55:00  76072.29  52671.04       57300   23401.25    44.42906
#
#                      운영예비력(MW)  운영예비율(퍼센트)
# 기준일시
# 2022-04-01 00:00:00    9257.45    14.82300
# 2022-04-01 00:05:00   10889.28    17.47058
# 2022-04-01 00:10:00   10865.86    17.57350
# 2022-04-01 00:15:00   10864.26    17.62284
# 2022-04-01 00:20:00   10451.95    17.02754
# ...                        ...         ...
# 2023-04-30 23:35:00    9389.09    17.44257
# 2023-04-30 23:40:00    8897.85    16.57166
# 2023-04-30 23:45:00    9257.95    17.48829
# 2023-04-30 23:50:00    9303.84    17.66110
# 2023-04-30 23:55:00    9508.00    18.05166
#
# [113643 rows x 7 columns]

# %%
df_ffff = pd.concat([df_ff,df_fff],axis=1)
df_ffff
# Out:
#                         기온(°C)   강수량(mm)   풍속(m/s)      습도(%)    일조(hr)  \
# 2022-04-01 00:00:00   6.180000  0.528571  1.849474  81.884211       NaN
# 2022-04-01 00:05:00   6.138684  0.496561  1.840789  81.989561       NaN
# 2022-04-01 00:10:00   6.097368  0.464550  1.832105  82.094912       NaN
# 2022-04-01 00:15:00   6.056053  0.432540  1.823421  82.200263       NaN
# 2022-04-01 00:20:00   6.014737  0.400529  1.814737  82.305614       NaN
# ...                        ...       ...       ...        ...       ...
# 2023-04-30 23:35:00  12.162294  0.395833  1.945116  66.985563  0.002105
# 2023-04-30 23:40:00  12.117961  0.426667  1.960885  67.230117  0.002105
# 2023-04-30 23:45:00  12.073627  0.457500  1.976653  67.474671  0.002105
# 2023-04-30 23:50:00  12.029293  0.488333  1.992421  67.719225  0.002105
# 2023-04-30 23:55:00  11.984959  0.519167  2.008190  67.963779  0.002105
#
#                       지면온도(°C)  현재수요(MW)
# 2022-04-01 00:00:00   6.186316  62453.29
# 2022-04-01 00:05:00   6.145965  62329.25
# 2022-04-01 00:10:00   6.105614  61830.96
# 2022-04-01 00:15:00   6.065263  61648.72
# 2022-04-01 00:20:00   6.024912  61382.62
# ...                        ...       ...
# 2023-04-30 23:35:00  10.846107  53828.62
# 2023-04-30 23:40:00  10.809386  53693.20
# 2023-04-30 23:45:00  10.772664  52937.98
# 2023-04-30 23:50:00  10.735943  52679.85
# 2023-04-30 23:55:00  10.699221  52671.04
#
# [113643 rows x 7 columns]

# %%
df_ffff = df_ffff.fillna(0)
df_ffff
# Out:
#                         기온(°C)   강수량(mm)   풍속(m/s)      습도(%)    일조(hr)  \
# 2022-04-01 00:00:00   6.180000  0.528571  1.849474  81.884211  0.000000
# 2022-04-01 00:05:00   6.138684  0.496561  1.840789  81.989561  0.000000
# 2022-04-01 00:10:00   6.097368  0.464550  1.832105  82.094912  0.000000
# 2022-04-01 00:15:00   6.056053  0.432540  1.823421  82.200263  0.000000
# 2022-04-01 00:20:00   6.014737  0.400529  1.814737  82.305614  0.000000
# ...                        ...       ...       ...        ...       ...
# 2023-04-30 23:35:00  12.162294  0.395833  1.945116  66.985563  0.002105
# 2023-04-30 23:40:00  12.117961  0.426667  1.960885  67.230117  0.002105
# 2023-04-30 23:45:00  12.073627  0.457500  1.976653  67.474671  0.002105
# 2023-04-30 23:50:00  12.029293  0.488333  1.992421  67.719225  0.002105
# 2023-04-30 23:55:00  11.984959  0.519167  2.008190  67.963779  0.002105
#
#                       지면온도(°C)  현재수요(MW)
# 2022-04-01 00:00:00   6.186316  62453.29
# 2022-04-01 00:05:00   6.145965  62329.25
# 2022-04-01 00:10:00   6.105614  61830.96
# 2022-04-01 00:15:00   6.065263  61648.72
# 2022-04-01 00:20:00   6.024912  61382.62
# ...                        ...       ...
# 2023-04-30 23:35:00  10.846107  53828.62
# 2023-04-30 23:40:00  10.809386  53693.20
# 2023-04-30 23:45:00  10.772664  52937.98
# 2023-04-30 23:50:00  10.735943  52679.85
# 2023-04-30 23:55:00  10.699221  52671.04
#
# [113643 rows x 7 columns]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt

# 필요한 가상정보와 전력수요 사이의 상관관계를 고려하여 입력 변수(X)와 출력 변수(y)로 분할
X = df_ffff[['기온(°C)', '강수량(mm)', '풍속(m/s)', '습도(%)', '일조(hr)', '지면온도(°C)']]
y = df_ffff['현재수요(MW)']

# 회귀분석 모델 학습
reg_model = LinearRegression()
reg_model.fit(X, y)

# 특정 기간의 데이터만 선택
start_date = '2023-03-13'
end_date = '2023-03-19'
filtered_X = X.loc[start_date:end_date]
filtered_y = y.loc[start_date:end_date]

# 테스트 데이터에 대한 예측
y_pred = reg_model.predict(filtered_X)

# MAPE 계산
mape = mean_absolute_percentage_error(filtered_y, y_pred)

# 결과 출력
print("Mean Absolute Percentage Error (MAPE):", mape)

# 그래프로 실제값과 예측값 나타내기
plt.plot(filtered_y.index, filtered_y, label='실제값')
plt.plot(filtered_y.index, y_pred, label='예측값')
plt.xlabel('기준일시')
plt.ylabel('전력수요(MW)')
plt.title('전력수요량 {} to {}'.format(start_date, end_date))
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# Mean Absolute Percentage Error (MAPE): 0.10089206548493479

# %% [markdown]
# # 회귀분석

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt

# 필요한 가상정보와 전력수요 사이의 상관관계를 고려하여 입력 변수(X)와 출력 변수(y)로 분할
X = df_ffff[['기온(°C)', '강수량(mm)', '풍속(m/s)', '습도(%)', '일조(hr)', '지면온도(°C)']]
y = df_ffff['현재수요(MW)']

# 특정 기간 필터링
start_date = '2022-04-01'
end_date = '2023-03-12'
filtered_X = X[(X.index >= start_date) & (X.index <= end_date)]
filtered_y = y[(y.index >= start_date) & (y.index <= end_date)]

# 회귀분석 모델 학습
reg_model = LinearRegression()
reg_model.fit(filtered_X, filtered_y)

# 특정 기간의 데이터만 선택
start_date = '2023-03-13'
end_date = '2023-03-19'
filtered_X = X.loc[start_date:end_date]
filtered_y = y.loc[start_date:end_date]

# 테스트 데이터에 대한 예측
y_pred = reg_model.predict(filtered_X)

# MAPE 계산
mape = mean_absolute_percentage_error(filtered_y, y_pred)

# 결과 출력
print("Mean Absolute Percentage Error (MAPE):", mape)

# 그래프로 실제값과 예측값 나타내기
plt.plot(filtered_y.index, filtered_y, label='실제값')
plt.plot(filtered_y.index, y_pred, label='예측값')
plt.xlabel('기준일시')
plt.ylabel('전력수요(MW)')
plt.title('전력수요량 {} to {}'.format(start_date, end_date))
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# Mean Absolute Percentage Error (MAPE): 0.11079588960093842

# %% [markdown]
# # 랜덤포레스트

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt

# 필요한 가상정보와 전력수요 사이의 상관관계를 고려하여 입력 변수(X)와 출력 변수(y)로 분할
X = df_ffff[['기온(°C)', '강수량(mm)', '풍속(m/s)', '습도(%)', '일조(hr)', '지면온도(°C)']]
y = df_ffff['현재수요(MW)']

# 특정 기간 필터링
start_date = '2022-04-01'
end_date = '2023-03-12'
filtered_X = X[(X.index >= start_date) & (X.index <= end_date)]
filtered_y = y[(y.index >= start_date) & (y.index <= end_date)]

# 모델 선택 및 학습
model = RandomForestRegressor()
model.fit(filtered_X, filtered_y)

# 특정 기간의 데이터만 선택
start_date = '2023-03-13'
end_date = '2023-03-19'
filtered_X = X.loc[start_date:end_date]
filtered_y = y.loc[start_date:end_date]

# 테스트 데이터에 대한 예측
y_pred = model.predict(filtered_X)

# MAPE 계산
mape = mean_absolute_percentage_error(filtered_y, y_pred)

# 결과 출력
print("Mean Absolute Percentage Error (MAPE):", mape)

# 그래프로 실제값과 예측값 나타내기
plt.plot(filtered_y.index, filtered_y, label='실제값')
plt.plot(filtered_y.index, y_pred, label='예측값')
plt.xlabel('기준일시')
plt.ylabel('전력수요(MW)')
plt.title('전력수요량 {} to {}'.format(start_date, end_date))
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# Mean Absolute Percentage Error (MAPE): 0.11282511909255995
